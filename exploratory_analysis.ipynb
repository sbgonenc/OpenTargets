# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Exploratory data analysis on moa, molecules(drugs) and targets datasets

# %% [markdown]
# # Mechanism of Action dataset

# %%
df_moa = pd.read_csv("moa.tsv", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_moa = pd.read_csv("moa.tsv", sep="\t")
#
# NameError: name 'pd' is not defined

# %%
df_moa
# Out:
#                          actionType  \
# 0                         INHIBITOR
# 1                         INHIBITOR
# 2     POSITIVE ALLOSTERIC MODULATOR
# 3                           AGONIST
# 4                         INHIBITOR
# ...                             ...
# 6181                        BLOCKER
# 6182                     ANTAGONIST
# 6183                      ACTIVATOR
# 6184                      INHIBITOR
# 6185                      INHIBITOR
#
#                                       mechanismOfAction  \
# 0                   Cyclin-dependent kinase 2 inhibitor
# 1        Vascular endothelial growth factor A inhibitor
# 2     GABA receptor alpha-3 subunit positive alloste...
# 3                    Beta-2 adrenergic receptor agonist
# 4           Transforming growth factor beta-3 inhibitor
# ...                                                 ...
# 6181            Sulfonylurea receptor 1, Kir6.2 blocker
# 6182          Type-1 angiotensin II receptor antagonist
# 6183  Cystic fibrosis transmembrane conductance regu...
# 6184                     Cytochrome P450 17A1 inhibitor
# 6185     T-lymphocyte activation antigen CD86 inhibitor
#
#                                chemblIds  \
# 0                       ['CHEMBL384304']
# 1                      ['CHEMBL4297163']
# 2                      ['CHEMBL1783256']
# 3     ['CHEMBL3989798', 'CHEMBL1256786']
# 4                      ['CHEMBL1743022']
# ...                                  ...
# 6181                   ['CHEMBL4298005']
# 6182                    ['CHEMBL432162']
# 6183                   ['CHEMBL4650318']
# 6184                   ['CHEMBL2105738']
# 6185                   ['CHEMBL1201823']
#
#                                              targetName       targetType  \
# 0                             Cyclin-dependent kinase 2   single protein
# 1                  Vascular endothelial growth factor A   single protein
# 2                         GABA receptor alpha-3 subunit   single protein
# 3                            Beta-2 adrenergic receptor   single protein
# 4                     Transforming growth factor beta-3   single protein
# ...                                                 ...              ...
# 6181                    Sulfonylurea receptor 1, Kir6.2  protein complex
# 6182                     Type-1 angiotensin II receptor   single protein
# 6183  Cystic fibrosis transmembrane conductance regu...   single protein
# 6184                               Cytochrome P450 17A1   single protein
# 6185               T-lymphocyte activation antigen CD86   single protein
#
#                                      targets  \
# 0                        ['ENSG00000123374']
# 1                        ['ENSG00000112715']
# 2                        ['ENSG00000011677']
# 3                        ['ENSG00000169252']
# 4                        ['ENSG00000119699']
# ...                                      ...
# 6181  ['ENSG00000187486', 'ENSG00000006071']
# 6182                     ['ENSG00000144891']
# 6183                     ['ENSG00000001626']
# 6184                     ['ENSG00000148795']
# 6185                     ['ENSG00000114013']
#
#                                              references
# 0                                                    []
# 1     [{'source': 'PubMed', 'ids': ['10416607', '126...
# 2     [{'source': 'PubMed', 'ids': ['25493397', '254...
# 3     [{'source': 'FDA', 'ids': ['label/2016/022518s...
# 4     [{'source': 'PubMed', 'ids': ['21368745', '213...
# ...                                                 ...
# 6181  [{'source': 'PubMed', 'ids': ['11264248', '208...
# 6182  [{'source': 'PubMed', 'ids': ['11046101', '978...
# 6183  [{'source': 'Other', 'ids': ['https://tools.cf...
# 6184  [{'source': 'Other', 'ids': ['http://tokaiphar...
# 6185  [{'source': 'DailyMed', 'ids': ['setid=0836c6a...
#
# [6186 rows x 7 columns]

# %% [markdown]
# Looking at the data, we can use "targets" key to obtain "ENSG" ENSEMBL gene ids.
#
# ### QUESTION!
# Some rows have multiple CHEMBL ids, which should seem like similar molecule types. Should I consider them as equal or should I count them separately?

# %%
df_moa.drop_duplicates()
# Out:
#                          actionType  \
# 0                         INHIBITOR
# 1                         INHIBITOR
# 2     POSITIVE ALLOSTERIC MODULATOR
# 3                           AGONIST
# 4                         INHIBITOR
# ...                             ...
# 6181                        BLOCKER
# 6182                     ANTAGONIST
# 6183                      ACTIVATOR
# 6184                      INHIBITOR
# 6185                      INHIBITOR
#
#                                       mechanismOfAction  \
# 0                   Cyclin-dependent kinase 2 inhibitor
# 1        Vascular endothelial growth factor A inhibitor
# 2     GABA receptor alpha-3 subunit positive alloste...
# 3                    Beta-2 adrenergic receptor agonist
# 4           Transforming growth factor beta-3 inhibitor
# ...                                                 ...
# 6181            Sulfonylurea receptor 1, Kir6.2 blocker
# 6182          Type-1 angiotensin II receptor antagonist
# 6183  Cystic fibrosis transmembrane conductance regu...
# 6184                     Cytochrome P450 17A1 inhibitor
# 6185     T-lymphocyte activation antigen CD86 inhibitor
#
#                                chemblIds  \
# 0                       ['CHEMBL384304']
# 1                      ['CHEMBL4297163']
# 2                      ['CHEMBL1783256']
# 3     ['CHEMBL3989798', 'CHEMBL1256786']
# 4                      ['CHEMBL1743022']
# ...                                  ...
# 6181                   ['CHEMBL4298005']
# 6182                    ['CHEMBL432162']
# 6183                   ['CHEMBL4650318']
# 6184                   ['CHEMBL2105738']
# 6185                   ['CHEMBL1201823']
#
#                                              targetName       targetType  \
# 0                             Cyclin-dependent kinase 2   single protein
# 1                  Vascular endothelial growth factor A   single protein
# 2                         GABA receptor alpha-3 subunit   single protein
# 3                            Beta-2 adrenergic receptor   single protein
# 4                     Transforming growth factor beta-3   single protein
# ...                                                 ...              ...
# 6181                    Sulfonylurea receptor 1, Kir6.2  protein complex
# 6182                     Type-1 angiotensin II receptor   single protein
# 6183  Cystic fibrosis transmembrane conductance regu...   single protein
# 6184                               Cytochrome P450 17A1   single protein
# 6185               T-lymphocyte activation antigen CD86   single protein
#
#                                      targets  \
# 0                        ['ENSG00000123374']
# 1                        ['ENSG00000112715']
# 2                        ['ENSG00000011677']
# 3                        ['ENSG00000169252']
# 4                        ['ENSG00000119699']
# ...                                      ...
# 6181  ['ENSG00000187486', 'ENSG00000006071']
# 6182                     ['ENSG00000144891']
# 6183                     ['ENSG00000001626']
# 6184                     ['ENSG00000148795']
# 6185                     ['ENSG00000114013']
#
#                                              references
# 0                                                    []
# 1     [{'source': 'PubMed', 'ids': ['10416607', '126...
# 2     [{'source': 'PubMed', 'ids': ['25493397', '254...
# 3     [{'source': 'FDA', 'ids': ['label/2016/022518s...
# 4     [{'source': 'PubMed', 'ids': ['21368745', '213...
# ...                                                 ...
# 6181  [{'source': 'PubMed', 'ids': ['11264248', '208...
# 6182  [{'source': 'PubMed', 'ids': ['11046101', '978...
# 6183  [{'source': 'Other', 'ids': ['https://tools.cf...
# 6184  [{'source': 'Other', 'ids': ['http://tokaiphar...
# 6185  [{'source': 'DailyMed', 'ids': ['setid=0836c6a...
#
# [6186 rows x 7 columns]

# %%
df_moa.nunique()
# Out:
# actionType             27
# mechanismOfAction    1641
# chemblIds            4897
# targetName           1244
# targetType              9
# targets              1104
# references           4592
# dtype: int64

# %%
df_moa.isna().sum()
# Out:
# actionType           0
# mechanismOfAction    0
# chemblIds            0
# targetName           0
# targetType           0
# targets              0
# references           0
# dtype: int64

# %%
df_moa.groupby("actionType")["chemblIds"].nunique().plot.pie(y="CHEMBLID_counts", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='chemblIds'>

# %% [markdown]
# The main drug actiontypes seem to be Inhibitors with moderate anounts of Agonists and Antagonists

# %%
df_moa.groupby("targetType")["chemblIds"].nunique().plot.pie(y="CHEMBLID_counts", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='chemblIds'>

# %% [markdown]
# It seems single protein target type dominates the others, while proein family and protein complex groups have moderate percentage amounts.

# %%
df_moa.groupby("targetName")["chemblIds"].nunique().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='targetName'>

# %%
df_moa.groupby("mechanismOfAction")["chemblIds"].nunique().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='mechanismOfAction'>

# %% [markdown]
# 10 most mechanisms of action use inhibitor, antagonist and blocker strategies. These drugs should be designed againts bacterial infections, allergies, sugar methobolism and depression/anxiety. It may be interesting to see if diagnosed cases also correlate with this findings, but that is for another day :)

# %%
## Simplify the MoA dataset
df_moa_simplified = df_moa.drop(columns=["references", "mechanismOfAction", "targetName"])

# %%
df_moa_simplified["chemblIds"] = df_moa_simplified["chemblIds"].apply(lambda x: convert_to_list(x))
df_moa_simplified["targets"] = df_moa_simplified["targets"].apply(lambda x: convert_to_list(x))

# %%
df_moa_simplified_expChemId = df_moa_simplified.explode("chemblIds")

# %%
df_moa_simplified_expChemId_expTar = df_moa_simplified_expChemId.explode("targets")

# %%
df_moa_simplified_expChemId_expTar[(df_moa_simplified_expChemId_expTar["targets"]=="ENSG00000144285") & (df_moa_simplified_expChemId_expTar["chemblIds"]=="CHEMBL1769")]
# Out:
#      actionType                     mechanismOfAction   chemblIds  \
# 1950    BLOCKER  Sodium channel alpha subunit blocker  CHEMBL1769
#
#           targetType          targets
# 1950  protein family  ENSG00000144285

# %%
df_moa_simplified_expChemId_expTar[(df_moa_simplified_expChemId_expTar["targets"]=="ENSG00000144285") & (df_moa_simplified_expChemId_expTar["chemblIds"]=="CHEMBL1195")]
# Out:
#      actionType                     mechanismOfAction   chemblIds  \
# 1950    BLOCKER  Sodium channel alpha subunit blocker  CHEMBL1195
#
#           targetType          targets
# 1950  protein family  ENSG00000144285

# %% [markdown]
# I have simplified the MoA dataset by only keeping the columns I might need for task to be done. I have used "explode" method to flatten lists for chembl and target ids (i.e. converting them into singular rows), which will come handy when to combine with other datasets

# %%
## Save the progress
df_moa_simplified_expChemId_expTar.to_csv("preprocessed_moa.tsv", sep="\t", index=False)

# %% [markdown]
# Let's keep on exploring other datasets: Next Molecules
# # Molecules dataset

# %%
df_molecules = pd.read_csv("molecules.tsv", sep="\t")

# %%
df_molecules
# Out:
#                   id                                    canonicalSmiles  \
# 0       CHEMBL110739  C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)CC[C@@...
# 1         CHEMBL1195                     CCCOc1cc(N)ccc1C(=O)OCCN(CC)CC
# 2      CHEMBL1200632  CCCCCCCCCCCCCCCC(=O)O[C@@H]1[C@@H](O)[C@@H](O)...
# 3      CHEMBL1200691                       CC(=O)[O-].CC(=O)[O-].[Mg+2]
# 4       CHEMBL121790             Cc1cccc(-c2nn3c(c2-c2ccc(F)cc2)CCC3)n1
# ...              ...                                                ...
# 17106   CHEMBL474579  CO[C@@]1(NC(=O)C2SC(=C(C(N)=O)C(=O)O)S2)C(=O)N...
# 17107   CHEMBL503565                   CC/C=C(\C)C1(CC)C(=O)NC(=O)NC1=O
# 17108  CHEMBL5090754  CC1(C)CC[C@H](Nc2ncc(C(F)(F)F)c(-c3c[nH]c4c(P(...
# 17109   CHEMBL566834  Cn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(Nc3cccc(COCC(...
# 17110      CHEMBL720                                         OCc1ccccc1
#
#                           inchiKey        drugType  blackBoxWarning  \
# 0      OMFXVFTZEKFJBZ-HJTSIMOOSA-N  Small molecule            False
# 1      CAJIGINSTLKQMM-UHFFFAOYSA-N  Small molecule            False
# 2      GTNDZRUWKHDICY-DJHAJVGHSA-N  Small molecule             True
# 3      UEGPKNKPLBYCNK-UHFFFAOYSA-L  Small molecule            False
# 4      NBDZLUOYAAVYHF-UHFFFAOYSA-N  Small molecule            False
# ...                            ...             ...              ...
# 17106  SRZNHPXWXCNNDU-IXOPCIAXSA-N  Small molecule            False
# 17107  RAFOHKSPUDGZPR-VOTSOKGWSA-N  Small molecule            False
# 17108  JDJOUBVVSQDIRC-AWEZNQCLSA-N  Small molecule            False
# 17109  XWTBASUJPOEBBZ-UHFFFAOYSA-N  Small molecule            False
# 17110  WVDDGKGOMKODPV-UHFFFAOYSA-N  Small molecule            False
#
#                                       name  maximumClinicalTrialPhase  \
# 0                           CORTICOSTERONE                        3.0
# 1                             PROPOXYCAINE                        4.0
# 2      CLINDAMYCIN PALMITATE HYDROCHLORIDE                        4.0
# 3                        MAGNESIUM ACETATE                        4.0
# 4                             CHEMBL121790                        NaN
# ...                                    ...                        ...
# 17106                            CEFOTETAN                        4.0
# 17107                          VINBARBITAL                       -1.0
# 17108                              SY-5609                        1.0
# 17109                         CHEMBL566834                        NaN
# 17110                       BENZYL ALCOHOL                        4.0
#
#        hasBeenWithdrawn isApproved  \
# 0                 False      False
# 1                 False       True
# 2                 False       True
# 3                 False       True
# 4                 False        NaN
# ...                 ...        ...
# 17106             False       True
# 17107             False      False
# 17108             False      False
# 17109             False        NaN
# 17110             False       True
#
#                                               tradeNames  ...  \
# 0                                                     []  ...
# 1                                                     []  ...
# 2      ['Cleocin', 'Clindamycin palmitate hydrochlori...  ...
# 3                                                     []  ...
# 4                                                     []  ...
# ...                                                  ...  ...
# 17106                                        ['Cefotan']  ...
# 17107                                                 []  ...
# 17108                                                 []  ...
# 17109                                                 []  ...
# 17110                                        ['Ulesfia']  ...
#
#                                      linkedDiseases.rows linkedDiseases.count  \
# 0                                        ['EFO_1000786']                  1.0
# 1                                                    NaN                  NaN
# 2          ['EFO_0003894', 'EFO_0000544', 'EFO_0003102']                  3.0
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 17106  ['HP_0001082', 'EFO_0000771', 'EFO_0000544', '...                  4.0
# 17107                                                NaN                  NaN
# 17108    ['MONDO_0007254', 'EFO_0000702', 'EFO_0002618']                  3.0
# 17109                                                NaN                  NaN
# 17110  ['EFO_0009560', 'EFO_0001067', 'HP_0000989', '...                  4.0
#
#       yearOfFirstApproval     childChemblIds  \
# 0                     NaN                NaN
# 1                  1982.0     ['CHEMBL1769']
# 2                  1986.0                NaN
# 3                     NaN  ['CHEMBL3989858']
# 4                     NaN                NaN
# ...                   ...                ...
# 17106              1985.0  ['CHEMBL1201098']
# 17107                 NaN  ['CHEMBL2107295']
# 17108                 NaN                NaN
# 17109                 NaN                NaN
# 17110              2009.0                NaN
#
#                                       linkedTargets.rows linkedTargets.count  \
# 0                                                    NaN                 NaN
# 1      ['ENSG00000144285', 'ENSG00000183873', 'ENSG00...                10.0
# 2                                                     []                 0.0
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 17106                                                 []                 0.0
# 17107                                                NaN                 NaN
# 17108                                                NaN                 NaN
# 17109                                                NaN                 NaN
# 17110                                                NaN                 NaN
#
#             parentId                     crossReferences.DailyMed  \
# 0                NaN                                          NaN
# 1                NaN                                          NaN
# 2      CHEMBL1201289  ['clindamycin%20palmitate%20hydrochloride']
# 3                NaN                      ['magnesium%20acetate']
# 4                NaN                                          NaN
# ...              ...                                          ...
# 17106            NaN                     ['cefotetan%20disodium']
# 17107            NaN                                          NaN
# 17108            NaN                                          NaN
# 17109            NaN                                          NaN
# 17110            NaN                                          NaN
#
#        crossReferences.DrugCentral crossReferences.TG-GATEs
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                         ['4489']                      NaN
# 4                              NaN                      NaN
# ...                            ...                      ...
# 17106                          NaN                      NaN
# 17107                          NaN                      NaN
# 17108                          NaN                      NaN
# 17109                          NaN                      NaN
# 17110                          NaN                      NaN
#
# [17111 rows x 26 columns]

# %% [markdown]
# We can use CHEMBL ids to match molecules (drugs) with Mechanism of Action data.

# %%
df_molecules.nunique()
# Out:
# id                             17111
# canonicalSmiles                14496
# inchiKey                       14496
# drugType                          10
# blackBoxWarning                    2
# name                           16985
# maximumClinicalTrialPhase          6
# hasBeenWithdrawn                   2
# isApproved                         2
# tradeNames                      3125
# synonyms                       11199
# description                     3255
# crossReferences.PubChem         3979
# crossReferences.Wikipedia       2719
# crossReferences.drugbank        7608
# crossReferences.chEBI           3742
# linkedDiseases.rows             5629
# linkedDiseases.count             135
# yearOfFirstApproval               84
# childChemblIds                  2921
# linkedTargets.rows              1429
# linkedTargets.count               33
# parentId                        1319
# crossReferences.DailyMed        1614
# crossReferences.DrugCentral      387
# crossReferences.TG-GATEs         113
# dtype: int64

# %%
df_molecules.isna().sum()
# Out:
# id                                 0
# canonicalSmiles                 2615
# inchiKey                        2615
# drugType                           0
# blackBoxWarning                    0
# name                               0
# maximumClinicalTrialPhase       6773
# hasBeenWithdrawn                   0
# isApproved                      6773
# tradeNames                         0
# synonyms                           0
# description                        0
# crossReferences.PubChem        13132
# crossReferences.Wikipedia      14381
# crossReferences.drugbank        9503
# crossReferences.chEBI          13369
# linkedDiseases.rows             8386
# linkedDiseases.count            8386
# yearOfFirstApproval            14027
# childChemblIds                 14190
# linkedTargets.rows             11497
# linkedTargets.count            11497
# parentId                       15672
# crossReferences.DailyMed       14984
# crossReferences.DrugCentral    16724
# crossReferences.TG-GATEs       16998
# dtype: int64

# %%
df_molecules.groupby("drugType")["id"].nunique().plot.pie(autopct='%1.2f%%')
# Out:
# <Axes: ylabel='id'>

# %%
df_molecules.groupby("drugType")["id"].nunique().plot(kind="bar")
# Out:
# <Axes: xlabel='drugType'>

# %% [markdown]
# Majority of the drug type consists of small molecules, with some antibodies and proteins.

# %%
fltr = df_molecules["id"] == "CHEMBL2107295"

# %%
df_molecules[fltr]
# Out:
# Empty DataFrame
# Columns: [id, canonicalSmiles, inchiKey, drugType, blackBoxWarning, name, maximumClinicalTrialPhase, hasBeenWithdrawn, isApproved, tradeNames, synonyms, description, crossReferences.PubChem, crossReferences.Wikipedia, crossReferences.drugbank, crossReferences.chEBI, linkedDiseases.rows, linkedDiseases.count, yearOfFirstApproval, childChemblIds, linkedTargets.rows, linkedTargets.count, parentId, crossReferences.DailyMed, crossReferences.DrugCentral, crossReferences.TG-GATEs]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## QUESTION!
# Some chembl ids have child or parent ids. does it mean they are similar? Should I account them as one by one, or group them?

# %%
## Simplify molecules dataframe

df_molecules_simplified = df_molecules[["id", "drugType", "childChemblIds", "parentId", "linkedTargets.rows"]]

# %%
df_molecules_simplified[df_molecules_simplified["id"] == "CHEMBL1769"]
# Out:
#               id        drugType childChemblIds    parentId  \
# 4562  CHEMBL1769  Small molecule            NaN  CHEMBL1195
#
#                                      linkedTargets.rows
# 4562  ['ENSG00000144285', 'ENSG00000183873', 'ENSG00...

# %%
df_molecules_simplified
# Out:
#                   id        drugType     childChemblIds       parentId  \
# 0       CHEMBL110739  Small molecule                NaN            NaN
# 1         CHEMBL1195  Small molecule     ['CHEMBL1769']            NaN
# 2      CHEMBL1200632  Small molecule                NaN  CHEMBL1201289
# 3      CHEMBL1200691  Small molecule  ['CHEMBL3989858']            NaN
# 4       CHEMBL121790  Small molecule                NaN            NaN
# ...              ...             ...                ...            ...
# 17106   CHEMBL474579  Small molecule  ['CHEMBL1201098']            NaN
# 17107   CHEMBL503565  Small molecule  ['CHEMBL2107295']            NaN
# 17108  CHEMBL5090754  Small molecule                NaN            NaN
# 17109   CHEMBL566834  Small molecule                NaN            NaN
# 17110      CHEMBL720  Small molecule                NaN            NaN
#
#                                       linkedTargets.rows
# 0                                                    NaN
# 1      ['ENSG00000144285', 'ENSG00000183873', 'ENSG00...
# 2                                                     []
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17106                                                 []
# 17107                                                NaN
# 17108                                                NaN
# 17109                                                NaN
# 17110                                                NaN
#
# [17111 rows x 5 columns]

# %%
df_molecules_simplified["childChemblIds"]
# Out:
# 0                      NaN
# 1           ['CHEMBL1769']
# 2                      NaN
# 3        ['CHEMBL3989858']
# 4                      NaN
#                ...
# 17106    ['CHEMBL1201098']
# 17107    ['CHEMBL2107295']
# 17108                  NaN
# 17109                  NaN
# 17110                  NaN
# Name: childChemblIds, Length: 17111, dtype: object

# %%
df_molecules_simplified["childChemblIds"] = df_molecules_simplified["childChemblIds"].apply(lambda x: convert_to_list(x))
df_molecules_simplified["linkedTargets.rows"] = df_molecules_simplified["linkedTargets.rows"].apply(lambda x: convert_to_list(x))
# Out:
# /tmp/ipykernel_5459/4211579397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_molecules_simplified["childChemblIds"] = df_molecules_simplified["childChemblIds"].apply(lambda x: convert_to_list(x))
# /tmp/ipykernel_5459/4211579397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_molecules_simplified["linkedTargets.rows"] = df_molecules_simplified["linkedTargets.rows"].apply(lambda x: convert_to_list(x))

# %%
df_molecules_simplified_expChild = df_molecules_simplified.explode("childChemblIds")
df_molecules_simplified_expChild_expTarg = df_molecules_simplified_expChild.explode("linkedTargets.rows")

# %%
df_molecules_simplified_expChild_expTarg
# Out:
#                   id        drugType childChemblIds parentId  \
# 0       CHEMBL110739  Small molecule           None      NaN
# 1         CHEMBL1195  Small molecule     CHEMBL1769      NaN
# 1         CHEMBL1195  Small molecule     CHEMBL1769      NaN
# 1         CHEMBL1195  Small molecule     CHEMBL1769      NaN
# 1         CHEMBL1195  Small molecule     CHEMBL1769      NaN
# ...              ...             ...            ...      ...
# 17106   CHEMBL474579  Small molecule  CHEMBL1201098      NaN
# 17107   CHEMBL503565  Small molecule  CHEMBL2107295      NaN
# 17108  CHEMBL5090754  Small molecule           None      NaN
# 17109   CHEMBL566834  Small molecule           None      NaN
# 17110      CHEMBL720  Small molecule           None      NaN
#
#       linkedTargets.rows
# 0                   None
# 1        ENSG00000144285
# 1        ENSG00000183873
# 1        ENSG00000007314
# 1        ENSG00000136546
# ...                  ...
# 17106                NaN
# 17107                NaN
# 17108                NaN
# 17109                NaN
# 17110                NaN
#
# [28136 rows x 5 columns]

# %% [markdown]
# Similar to MoA df, I have used "explode" method to have separate rows for each CHEMBL IDs and Target Ensembl IDs

# %%
df_molecules_simplified_expChild_expTarg.to_csv("preprocessed_molecules.tsv", sep="\t", index=False)

# %% [markdown]
# And finally the big targets dataset.
# # Targets dataset

# %%
df_targets=pd.read_csv("targets.tsv", sep="\t")

# %%
df_targets
# Out:
#                     id   approvedSymbol               biotype  \
# 0      ENSG00000020219          CCT8L1P  processed_pseudogene
# 1      ENSG00000059588           TARBP1        protein_coding
# 2      ENSG00000070182             SPTB        protein_coding
# 3      ENSG00000070366             SMG6        protein_coding
# 4      ENSG00000072071           ADGRL1        protein_coding
# ...                ...              ...                   ...
# 63221  ENSG00000291063  ENSG00000291063                lncRNA
# 63222  ENSG00000291086         LGALS17A                lncRNA
# 63223  ENSG00000291302  ENSG00000291302        protein_coding
# 63224  ENSG00000292353         KRT18P53  processed_pseudogene
# 63225  ENSG00000293432  ENSG00000293432                lncRNA
#
#                                            transcriptIds  \
# 0                                    ['ENST00000465400']
# 1      ['ENST00000496673', 'ENST00000483404', 'ENST00...
# 2      ['ENST00000553938', 'ENST00000389720', 'ENST00...
# 3      ['ENST00000354901', 'ENST00000570756', 'ENST00...
# 4      ['ENST00000361434', 'ENST00000589616', 'ENST00...
# ...                                                  ...
# 63221  ['ENST00000687724', 'ENST00000700909', 'ENST00...
# 63222  ['ENST00000598304', 'ENST00000412609', 'ENST00...
# 63223                                ['ENST00000706625']
# 63224                                ['ENST00000711146']
# 63225                                ['ENST00000638124']
#
#                                           canonicalExons  \
# 0                             ['152445477', '152447150']
# 1      ['234420702', '234420812', '234425673', '23442...
# 2      ['64785537', '64785627', '64774397', '64774527...
# 3      ['2172658', '2172859', '2292871', '2292977', '...
# 4      ['14160112', '14160297', '14159401', '14159584...
# ...                                                  ...
# 63221                                                NaN
# 63222                                                NaN
# 63223                                                NaN
# 63224                                                NaN
# 63225                                                NaN
#
#                                             approvedName  \
# 0      chaperonin containing TCP1 subunit 8 like 1, p...
# 1                      TAR (HIV-1) RNA binding protein 1
# 2                            spectrin beta, erythrocytic
# 3               SMG6 nonsense mediated mRNA decay factor
# 4                 adhesion G protein-coupled receptor L1
# ...                                                  ...
# 63221                                   novel transcript
# 63222                            galectin 14 pseudogene
# 63223                                      novel protein
# 63224                          keratin 18 pseudogene 53
# 63225                                   novel transcript
#
#                                                 synonyms  \
# 0      [{'label': 'Putative T-complex protein 1 subun...
# 1      [{'label': 'Probable methyltransferase TARBP1'...
# 2      [{'label': 'Spectrin beta chain, erythrocytic'...
# 3      [{'label': 'Telomerase-binding protein EST1A',...
# 4      [{'label': 'Adhesion G protein-coupled recepto...
# ...                                                  ...
# 63221  [{'label': 'LOC107984974', 'source': 'NCBI_ent...
# 63222  [{'label': 'Charcot-Leyden crystal protein pse...
# 63223                                                 []
# 63224   [{'label': 'KRT18P53', 'source': 'NCBI_entrez'}]
# 63225                                                 []
#
#                                           symbolSynonyms  \
# 0      [{'label': 'CCT8L1P', 'source': 'uniprot'}, {'...
# 1      [{'label': 'TARBP1', 'source': 'uniprot'}, {'l...
# 2      [{'label': 'SPTB', 'source': 'uniprot'}, {'lab...
# 3      [{'label': 'SMG6', 'source': 'uniprot'}, {'lab...
# 4      [{'label': 'ADGRL1', 'source': 'uniprot'}, {'l...
# ...                                                  ...
# 63221  [{'label': 'LOC107984974', 'source': 'NCBI_ent...
# 63222   [{'label': 'LGALS17A', 'source': 'NCBI_entrez'}]
# 63223                                                 []
# 63224   [{'label': 'KRT18P53', 'source': 'NCBI_entrez'}]
# 63225                                                 []
#
#                                             nameSynonyms  \
# 0      [{'label': 'Putative T-complex protein 1 subun...
# 1      [{'label': 'Probable methyltransferase TARBP1'...
# 2      [{'label': 'Spectrin beta chain, erythrocytic'...
# 3      [{'label': 'Telomerase-binding protein EST1A',...
# 4      [{'label': 'Adhesion G protein-coupled recepto...
# ...                                                  ...
# 63221                                                 []
# 63222  [{'label': 'Charcot-Leyden crystal protein pse...
# 63223                                                 []
# 63224                                                 []
# 63225                                                 []
#
#                                     functionDescriptions  ...  \
# 0      ['Possible molecular chaperone; assists the fo...  ...
# 1      ['Probable S-adenosyl-L-methionine-dependent m...  ...
# 2      ['Spectrin is the major constituent of the cyt...  ...
# 3      ["Component of the telomerase ribonucleoprotei...  ...
# 4      ['Calcium-independent receptor of high affinit...  ...
# ...                                                  ...  ...
# 63221                                                NaN  ...
# 63222                                                NaN  ...
# 63223                                                NaN  ...
# 63224                                                NaN  ...
# 63225                                                NaN  ...
#
#                                                 pathways     alternativeGenes  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2      [{'pathwayId': 'R-HSA-6807878', 'pathway': 'CO...                  NaN
# 3      [{'pathwayId': 'R-HSA-975957', 'pathway': 'Non...                  NaN
# 4                                                    NaN  ['ENSG00000288324']
# ...                                                  ...                  ...
# 63221                                                NaN                  NaN
# 63222                                                NaN                  NaN
# 63223                                                NaN                  NaN
# 63224                                                NaN                  NaN
# 63225                                                NaN                  NaN
#
#       safetyLiabilities chemicalProbes hallmarks.attributes  \
# 0                   NaN            NaN                  NaN
# 1                   NaN            NaN                  NaN
# 2                   NaN            NaN                  NaN
# 3                   NaN            NaN                  NaN
# 4                   NaN            NaN                  NaN
# ...                 ...            ...                  ...
# 63221               NaN            NaN                  NaN
# 63222               NaN            NaN                  NaN
# 63223               NaN            NaN                  NaN
# 63224               NaN            NaN                  NaN
# 63225               NaN            NaN                  NaN
#
#       hallmarks.cancerHallmarks tep.targetFromSourceId  tep.description  \
# 0                           NaN                    NaN              NaN
# 1                           NaN                    NaN              NaN
# 2                           NaN                    NaN              NaN
# 3                           NaN                    NaN              NaN
# 4                           NaN                    NaN              NaN
# ...                         ...                    ...              ...
# 63221                       NaN                    NaN              NaN
# 63222                       NaN                    NaN              NaN
# 63223                       NaN                    NaN              NaN
# 63224                       NaN                    NaN              NaN
# 63225                       NaN                    NaN              NaN
#
#        tep.therapeuticArea tep.url
# 0                      NaN     NaN
# 1                      NaN     NaN
# 2                      NaN     NaN
# 3                      NaN     NaN
# 4                      NaN     NaN
# ...                    ...     ...
# 63221                  NaN     NaN
# 63222                  NaN     NaN
# 63223                  NaN     NaN
# 63224                  NaN     NaN
# 63225                  NaN     NaN
#
# [63226 rows x 39 columns]

# %%
df_targets.isna().sum()
# Out:
# id                                    0
# approvedSymbol                        0
# biotype                            1054
# transcriptIds                         0
# canonicalExons                     1912
# approvedName                       1403
# synonyms                              0
# symbolSynonyms                        0
# nameSynonyms                          0
# functionDescriptions              43040
# subcellularLocations              43040
# obsoleteSymbols                       0
# obsoleteNames                         0
# proteinIds                        42126
# dbXrefs                               0
# canonicalTranscript.id             1861
# canonicalTranscript.chromosome     1861
# canonicalTranscript.start          1861
# canonicalTranscript.end            1861
# canonicalTranscript.strand         1861
# genomicLocation.chromosome            0
# genomicLocation.start                 0
# genomicLocation.end                   0
# genomicLocation.strand                0
# go                                42255
# targetClass                       58460
# constraint                        44127
# homologues                        37733
# tractability                      43716
# pathways                          52040
# alternativeGenes                  62145
# safetyLiabilities                 62294
# chemicalProbes                    62362
# hallmarks.attributes              62883
# hallmarks.cancerHallmarks         62891
# tep.targetFromSourceId            63185
# tep.description                   63185
# tep.therapeuticArea               63185
# tep.url                           63185
# dtype: int64

# %% [markdown]
# we can identify rows by using ENSG ids, and get "subcellularLocations" to complete the task.

# %%
fltr = df_targets["id"] == "ENSG00000288324"

# %%
df_targets[fltr]
# Out:
# Empty DataFrame
# Columns: [id, approvedSymbol, biotype, transcriptIds, canonicalExons, approvedName, synonyms, symbolSynonyms, nameSynonyms, functionDescriptions, subcellularLocations, obsoleteSymbols, obsoleteNames, proteinIds, dbXrefs, canonicalTranscript.id, canonicalTranscript.chromosome, canonicalTranscript.start, canonicalTranscript.end, canonicalTranscript.strand, genomicLocation.chromosome, genomicLocation.start, genomicLocation.end, genomicLocation.strand, go, targetClass, constraint, homologues, tractability, pathways, alternativeGenes, safetyLiabilities, chemicalProbes, hallmarks.attributes, hallmarks.cancerHallmarks, tep.targetFromSourceId, tep.description, tep.therapeuticArea, tep.url]
# Index: []
#
# [0 rows x 39 columns]

# %%
df_targets.groupby("biotype")["id"].nunique()
# Out:
# biotype
# IG_C_gene                                14
# IG_C_pseudogene                           9
# IG_D_gene                                37
# IG_J_gene                                18
# IG_J_pseudogene                           3
# IG_V_gene                               146
# IG_V_pseudogene                         187
# IG_pseudogene                             1
# Mt_rRNA                                   2
# Mt_tRNA                                  22
# TR_C_gene                                 6
# TR_D_gene                                 5
# TR_J_gene                                79
# TR_J_pseudogene                           4
# TR_V_gene                               112
# TR_V_pseudogene                          33
# artifact                                 19
# lncRNA                                19370
# miRNA                                  1879
# misc_RNA                               2208
# processed_pseudogene                  10143
# protein_coding                        20082
# rRNA                                     47
# rRNA_pseudogene                         497
# ribozyme                                  8
# sRNA                                      5
# scRNA                                     1
# scaRNA                                   49
# snRNA                                  1901
# snoRNA                                  942
# transcribed_processed_pseudogene        513
# transcribed_unitary_pseudogene          158
# transcribed_unprocessed_pseudogene      962
# translated_processed_pseudogene           2
# unitary_pseudogene                      100
# unprocessed_pseudogene                 2604
# vault_RNA                                 4
# Name: id, dtype: int64

# %%
df_targets.groupby("subcellularLocations")["id"].nunique()
# Out:
# subcellularLocations
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1256
# [{'location': 'Actin filaments', 'source': 'HPA_main', 'termSL': 'SL-0090', 'labelSL': 'Cytoskeleton'}, {'location': 'Cytosol', 'source': 'HPA_additional', 'termSL': 'SL-0091', 'labelSL': 'Cytosol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3
# [{'location': 'Actin filaments', 'source': 'HPA_main', 'termSL': 'SL-0090', 'labelSL': 'Cytoskeleton'}, {'location': 'Cytosol', 'source': 'HPA_main', 'termSL': 'SL-0091', 'labelSL': 'Cytosol'}, {'location': 'Intermediate filaments', 'source': 'HPA_main', 'termSL': 'SL-0180', 'labelSL': 'Nucleus lamina'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [{'location': 'Actin filaments', 'source': 'HPA_main', 'termSL': 'SL-0090', 'labelSL': 'Cytoskeleton'}, {'location': 'Cytosol', 'source': 'HPA_main', 'termSL': 'SL-0091', 'labelSL': 'Cytosol'}, {'location': 'Nucleoplasm', 'source': 'HPA_main', 'termSL': 'SL-0190', 'labelSL': 'Nucleoplasm'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{'location': 'Actin filaments', 'source': 'HPA_main', 'termSL': 'SL-0090', 'labelSL': 'Cytoskeleton'}, {'location': 'Cytosol', 'source': 'HPA_main', 'termSL': 'SL-0091', 'labelSL': 'Cytosol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# [{'location': '[Tumor necrosis factor ligand superfamily member 14, membrane form]: Cell membrane', 'source': 'uniprot', 'termSL': 'SL-0039', 'labelSL': 'Cellular component'}, {'location': '[Tumor necrosis factor ligand superfamily member 14, soluble form]: Secreted', 'source': 'uniprot', 'termSL': 'SL-0243', 'labelSL': 'Cellular component'}, {'location': '[Isoform 2]: Cytoplasm', 'source': 'uniprot', 'termSL': 'SL-0086', 'labelSL': 'Cellular component'}, {'location': 'Vesicles', 'source': 'HPA_main', 'termSL': 'SL-0498', 'labelSL': 'Vesicle'}, {'location': 'Predicted to be secreted', 'source': 'HPA_extracellular_location'}]                                                                                                                                                          1
# [{'location': '[Ubiquitin]: Cytoplasm', 'source': 'uniprot', 'termSL': 'SL-0086', 'labelSL': 'Cellular component'}, {'location': 'Nucleus', 'source': 'uniprot', 'termSL': 'SL-0191', 'labelSL': 'Cellular component'}, {'location': 'Mitochondrion outer membrane', 'source': 'uniprot', 'termSL': 'SL-0172', 'labelSL': 'Cellular component'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                  2
# [{'location': '[Ubiquitin]: Cytoplasm', 'source': 'uniprot', 'termSL': 'SL-0086', 'labelSL': 'Cellular component'}, {'location': 'Nucleus', 'source': 'uniprot', 'termSL': 'SL-0191', 'labelSL': 'Cellular component'}, {'location': '[Large ribosomal subunit protein eL40]: Cytoplasm', 'source': 'uniprot', 'termSL': 'SL-0086', 'labelSL': 'Cellular component'}, {'location': 'Cytosol', 'source': 'HPA_main', 'termSL': 'SL-0091', 'labelSL': 'Cytosol'}, {'location': 'Endoplasmic reticulum', 'source': 'HPA_main', 'termSL': 'SL-0095', 'labelSL': 'Endoplasmic reticulum'}, {'location': 'Nucleoplasm', 'source': 'HPA_additional', 'termSL': 'SL-0190', 'labelSL': 'Nucleoplasm'}, {'location': 'Plasma membrane', 'source': 'HPA_additional', 'termSL': 'SL-0039', 'labelSL': 'Cell membrane'}]       1
# [{'location': '[Vascular cell adhesion protein 1]: Cell membrane', 'source': 'uniprot', 'termSL': 'SL-0039', 'labelSL': 'Cellular component'}, {'location': '[Soluble Vascular Cell Adhesion Molecule-1]: Secreted', 'source': 'uniprot', 'termSL': 'SL-0243', 'labelSL': 'Cellular component'}, {'location': 'Cell Junctions', 'source': 'HPA_main', 'termSL': 'SL-0038', 'labelSL': 'Cell junction'}]                                                                                                                                                                                                                                                                                                                                                                                                           1
# [{'location': '[Zona pellucida-like domain-containing protein 1]: Cytoplasmic vesicle membrane', 'source': 'uniprot', 'termSL': 'SL-0089', 'labelSL': 'Cellular component'}, {'location': '[Zona pellucida-like domain-containing protein 1, secreted form]: Secreted', 'source': 'uniprot', 'termSL': 'SL-0243', 'labelSL': 'Cellular component'}, {'location': 'Nucleoplasm', 'source': 'HPA_main', 'termSL': 'SL-0190', 'labelSL': 'Nucleoplasm'}]                                                                                                                                                                                                                                                                                                                                                             1
# Name: id, Length: 6954, dtype: int64

# %% [markdown]
# subcellular locations data looks a bit messy. We can mutate to get "locations" and "labelSL" columns

# %%
## Simplify the dataset
## narrow down the rows with no subcellular data
df_targets_naless = df_targets.dropna(subset=['subcellularLocations'])

## keep useful columns
columns_to_keep = ["id","biotype", "alternativeGenes", "subcellularLocations"]
df_targets_simplified = df_targets_naless[columns_to_keep]

# %%
df_targets_simplified
# Out:
#                     id               biotype     alternativeGenes  \
# 0      ENSG00000020219  processed_pseudogene                  NaN
# 1      ENSG00000059588        protein_coding                  NaN
# 2      ENSG00000070182        protein_coding                  NaN
# 3      ENSG00000070366        protein_coding                  NaN
# 4      ENSG00000072071        protein_coding  ['ENSG00000288324']
# ...                ...                   ...                  ...
# 63100  ENSG00000236383        protein_coding                  NaN
# 63139  ENSG00000259224        protein_coding  ['ENSG00000284515']
# 63157  ENSG00000269526        protein_coding                  NaN
# 63180  ENSG00000278848        protein_coding                  NaN
# 63190  ENSG00000284479        protein_coding                  NaN
#
#                                     subcellularLocations
# 0      [{'location': 'Cytoplasm', 'source': 'uniprot'...
# 1      [{'location': 'Nuclear speckles', 'source': 'H...
# 2      [{'location': 'Cytoplasm', 'source': 'uniprot'...
# 3      [{'location': 'Nucleus', 'source': 'uniprot', ...
# 4      [{'location': 'Cell membrane', 'source': 'unip...
# ...                                                  ...
# 63100                                                 []
# 63139  [{'location': 'Membrane', 'source': 'uniprot',...
# 63157  [{'location': 'Membrane', 'source': 'uniprot',...
# 63180  [{'location': 'Cytoplasm', 'source': 'uniprot'...
# 63190  [{'location': 'Membrane', 'source': 'uniprot',...
#
# [20186 rows x 4 columns]

# %%
df_targets_simplified[df_targets_simplified["id"] == "ENSG00000154640"]
# Out:
#                     id         biotype alternativeGenes subcellularLocations
# 62969  ENSG00000154640  protein_coding              NaN                   []

# %%
## handle the subcellularLocations
# convert string to an array
df_targets_simplified["subcellularLocations"] = df_targets_simplified["subcellularLocations"].apply(lambda x: convert_to_list(x))
df_targets_simplified_exp_locs = df_targets_simplified.explode("subcellularLocations")
# Out:
# /tmp/ipykernel_10067/4228390719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets_simplified["subcellularLocations"] = df_targets_simplified["subcellularLocations"].apply(lambda x: convert_to_list(x))

# %%
df_targets_simplified_exp_locs
# Out:
#                     id               biotype alternativeGenes  \
# 0      ENSG00000020219  processed_pseudogene              NaN
# 1      ENSG00000059588        protein_coding              NaN
# 2      ENSG00000070182        protein_coding              NaN
# 2      ENSG00000070182        protein_coding              NaN
# 3      ENSG00000070366        protein_coding              NaN
# ...                ...                   ...              ...
# 63157  ENSG00000269526        protein_coding              NaN
# 63180  ENSG00000278848        protein_coding              NaN
# 63180  ENSG00000278848        protein_coding              NaN
# 63180  ENSG00000278848        protein_coding              NaN
# 63190  ENSG00000284479        protein_coding              NaN
#
#                                     subcellularLocations
# 0      {'location': 'Cytoplasm', 'source': 'uniprot',...
# 1      {'location': 'Nuclear speckles', 'source': 'HP...
# 2      {'location': 'Cytoplasm', 'source': 'uniprot',...
# 2      {'location': 'Cytosol', 'source': 'HPA_main', ...
# 3      {'location': 'Nucleus', 'source': 'uniprot', '...
# ...                                                  ...
# 63157  {'location': 'Centrosome', 'source': 'HPA_addi...
# 63180  {'location': 'Cytoplasm', 'source': 'uniprot',...
# 63180  {'location': 'Nucleus', 'source': 'uniprot', '...
# 63180  {'location': 'Centriolar satellite', 'source':...
# 63190  {'location': 'Membrane', 'source': 'uniprot', ...
#
# [54040 rows x 4 columns]

# %%
df_targets_simplified_exp_locs = df_targets_simplified_exp_locs.dropna(subset=["subcellularLocations"])

# %%
df_targets_simplified_exp_locs[["subcellular_location", "subcellular_location_label"]] = df_targets_simplified_exp_locs["subcellularLocations"].apply(lambda x: pd.Series(get_loc_values(x)))
# Out:
# /tmp/ipykernel_10067/1998576961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets_simplified_exp_locs[["subcellular_location", "subcellular_location_label"]] = df_targets_simplified_exp_locs["subcellularLocations"].apply(lambda x: pd.Series(get_loc_values(x)))
# /tmp/ipykernel_10067/1998576961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets_simplified_exp_locs[["subcellular_location", "subcellular_location_label"]] = df_targets_simplified_exp_locs["subcellularLocations"].apply(lambda x: pd.Series(get_loc_values(x)))

# %% [markdown]
# ### Explode method
# After dropping nan values in subcellularLocations column, I have exploded to values to have each row with unique location. I realised about 1200 entry turned into NaN values, which is unusual. I figured that some "subcellularLocations" values turned to NaN were initially empty array [], hence needed to be dropped.
# A couple lines below are regarding this

# %%
df_targets_simplified_exp_locs[df_targets_simplified_exp_locs["subcellularLocations"].isna() == True]
# Out:
#                     id         biotype     alternativeGenes  \
# 35     ENSG00000136206  protein_coding                  NaN
# 52     ENSG00000162888          lncRNA                  NaN
# 84     ENSG00000188938  protein_coding                  NaN
# 91     ENSG00000198870  protein_coding  ['ENSG00000281245']
# 99     ENSG00000203804          lncRNA                  NaN
# ...                ...             ...                  ...
# 62969  ENSG00000154640  protein_coding                  NaN
# 62982  ENSG00000165509  protein_coding                  NaN
# 63010  ENSG00000187026  protein_coding                  NaN
# 63064  ENSG00000226490  protein_coding  ['ENSG00000291474']
# 63100  ENSG00000236383  protein_coding                  NaN
#
#       subcellularLocations
# 35                     NaN
# 52                     NaN
# 84                     NaN
# 91                     NaN
# 99                     NaN
# ...                    ...
# 62969                  NaN
# 62982                  NaN
# 63010                  NaN
# 63064                  NaN
# 63100                  NaN
#
# [1256 rows x 4 columns]

# %%
df_targets_simplified_exp_locs[df_targets_simplified_exp_locs["id"] == "ENSG00000154640"]
# Out:
#                     id         biotype alternativeGenes subcellularLocations
# 62969  ENSG00000154640  protein_coding              NaN                  NaN

# %%
df_targets_simplified_exp_locs["subcellularLocations"].iloc[3]["location"]
# Out:
# 'Cytosol'

# %%
df_targets_simplified[df_targets_simplified["id"] == "ENSG00000154640"]

# %%
df_targets_simplified_exp_locs
# Out:
#                     id               biotype alternativeGenes  \
# 0      ENSG00000020219  processed_pseudogene              NaN
# 1      ENSG00000059588        protein_coding              NaN
# 2      ENSG00000070182        protein_coding              NaN
# 2      ENSG00000070182        protein_coding              NaN
# 3      ENSG00000070366        protein_coding              NaN
# ...                ...                   ...              ...
# 63157  ENSG00000269526        protein_coding              NaN
# 63180  ENSG00000278848        protein_coding              NaN
# 63180  ENSG00000278848        protein_coding              NaN
# 63180  ENSG00000278848        protein_coding              NaN
# 63190  ENSG00000284479        protein_coding              NaN
#
#                                     subcellularLocations  \
# 0      {'location': 'Cytoplasm', 'source': 'uniprot',...
# 1      {'location': 'Nuclear speckles', 'source': 'HP...
# 2      {'location': 'Cytoplasm', 'source': 'uniprot',...
# 2      {'location': 'Cytosol', 'source': 'HPA_main', ...
# 3      {'location': 'Nucleus', 'source': 'uniprot', '...
# ...                                                  ...
# 63157  {'location': 'Centrosome', 'source': 'HPA_addi...
# 63180  {'location': 'Cytoplasm', 'source': 'uniprot',...
# 63180  {'location': 'Nucleus', 'source': 'uniprot', '...
# 63180  {'location': 'Centriolar satellite', 'source':...
# 63190  {'location': 'Membrane', 'source': 'uniprot', ...
#
#        subcellular_location subcellular_location_label
# 0                 Cytoplasm         Cellular component
# 1          Nuclear speckles            Nucleus speckle
# 2                 Cytoplasm         Cellular component
# 2                   Cytosol                    Cytosol
# 3                   Nucleus         Cellular component
# ...                     ...                        ...
# 63157            Centrosome                 Centrosome
# 63180             Cytoplasm         Cellular component
# 63180               Nucleus         Cellular component
# 63180  Centriolar satellite       Centriolar satellite
# 63190              Membrane         Cellular component
#
# [52784 rows x 6 columns]

# %%
df_targets_simplified_exp_locs.drop(columns=["subcellularLocations"], inplace=True)
# Out:
# /tmp/ipykernel_10067/1502703420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets_simplified_exp_locs.drop(columns=["subcellularLocations"], inplace=True)

# %%
## Get location values
def get_loc_values(x:dict):
    try:
        return x.get("location", None), x.get("labelSL", None)
    except Exception as error:
        print(x)
        raise error

# %%
# Function to convert string to list
import ast
import numpy as np
def convert_to_list(string):
    if string in {None, np.nan}: return None
    try:
        return ast.literal_eval(string)
    except (ValueError, SyntaxError) as e:
        print(f"Error at\n {string}")
    raise e

# %%
## Get location counts
import json
locations_count = {}
sl_labels_count = {}
for entry in df_targets_simplified["subcellularLocations"]:
    #locs_array = convert_to_list(entry)
    locs_array = entry
    if locs_array == []: continue
    for loc_dict in locs_array:
        loc = loc_dict["location"]
            
        if loc in locations_count:
            locations_count[loc] += 1
        else:
            locations_count[loc] = 1
        ## Some entries do not contain labelSL key
        if "labelSL" not in loc_dict: continue 
        lable = loc_dict["labelSL"]
        if lable in sl_labels_count:
            sl_labels_count[lable] += 1
        else:
            sl_labels_count[lable] = 1

# %%
locations_count
# Out:
# {'Cytoplasm': 5291,
#  'Nuclear speckles': 486,
#  'Cytosol': 4834,
#  'Nucleus': 5130,
#  'Chromosome': 591,
#  'Nucleoli': 1065,
#  'Cell membrane': 3350,
#  'Cell projection': 975,
#  'Presynaptic cell membrane': 40,
#  'Synapse': 131,
#  'Nucleoplasm': 6102,
#  'Secreted': 1781,
#  'Membrane': 1660,
#  'Endoplasmic reticulum': 896,
#  'Golgi apparatus': 1685,
#  'Endoplasmic reticulum membrane': 874,
#  'Vesicles': 2212,
#  'Nucleoli rim': 149,
#  'Nucleoli fibrillar center': 309,
#  'Mitochondrion inner membrane': 323,
#  'Mitochondria': 1102,
#  'Endosome': 101,
#  'Apical cell membrane': 207,
#  'Mitochondrion': 581,
#  'Mitochondrion outer membrane': 148,
#  'Golgi apparatus membrane': 421,
#  'Endosome membrane': 152,
#  'Lysosome membrane': 217,
#  'Late endosome membrane': 117,
#  'Early endosome membrane': 141,
#  'Melanosome membrane': 16,
#  'Plasma membrane': 2054,
#  '[Isoform 3]: Cell surface': 2,
#  'Focal adhesion sites': 136,
#  'Basolateral cell membrane': 115,
#  'Perikaryon': 94,
#  'Nuclear bodies': 584,
#  'Lateral cell membrane': 17,
#  'Cell junction': 361,
#  'Actin filaments': 237,
#  '[Isoform p56]: Nucleus': 1,
#  '[Isoform p30]: Cytoplasm': 1,
#  'Midbody ring': 23,
#  'Early endosome': 125,
#  'Recycling endosome': 53,
#  'Postsynaptic density': 80,
#  'Cytoplasmic vesicle': 565,
#  'Mitochondrion membrane': 98,
#  'Mitochondrion intermembrane space': 44,
#  'Cytoplasmic bodies': 71,
#  'Nuclear membrane': 272,
#  'Cytoplasmic vesicle membrane': 134,
#  'Microtubules': 257,
#  '[Processed cyclic AMP-responsive element-binding protein 3-like protein 2]: Nucleus': 1,
#  'Postsynaptic cell membrane': 126,
#  'Nucleus matrix': 57,
#  'Mitotic spindle': 92,
#  'Centriolar satellite': 187,
#  'Peroxisome': 55,
#  'Peroxisomes': 23,
#  'Predicted to be secreted': 688,
#  'Melanosome': 76,
#  'Cytokinetic bridge': 156,
#  'Nucleus membrane': 91,
#  '[Isoform 2]: Endoplasmic reticulum': 9,
#  'Centrosome': 387,
#  'Postsynapse': 20,
#  '[Isoform 3]: Cytoplasm': 65,
#  'Cell Junctions': 325,
#  'Intermediate filaments': 162,
#  'Midbody': 128,
#  'Mitotic chromosome': 74,
#  'Lysosome': 118,
#  'Peroxisome membrane': 40,
#  'Endoplasmic reticulum lumen': 65,
#  'Microsome membrane': 74,
#  'Nucleus speckle': 191,
#  'Mitochondrion matrix': 185,
#  'Recycling endosome membrane': 82,
#  '[Isoform 3]: Secreted': 46,
#  '[Isoform 4]: Cell membrane': 20,
#  'Late endosome': 47,
#  '[Isoform A]: Cytoplasm': 3,
#  '[Isoform B]: Nucleus': 1,
#  '[Isoform C]: Nucleus': 2,
#  'Lysosome lumen': 11,
#  'Rough endoplasmic reticulum': 17,
#  'Nucleus outer membrane': 18,
#  'Nucleus envelope': 70,
#  'Presynapse': 38,
#  'Cleavage furrow': 40,
#  '[Isoform 2]: Nucleus speckle': 3,
#  'Cytoplasmic granule': 65,
#  'Cytolytic granule': 7,
#  'Membrane raft': 74,
#  'Lipid droplets': 39,
#  '[Isoform 1]: Nucleus': 68,
#  '[Isoform 2]: Endoplasmic reticulum membrane': 13,
#  '[P-beta]: Nucleus': 1,
#  'Endomembrane system': 79,
#  'Lipid droplet': 61,
#  '[Isoform 3]: Nucleus': 32,
#  '[Isoform 2]: Nucleus': 59,
#  '[Isoform 3]: Mitochondrion': 3,
#  'Cell surface': 53,
#  '[Isoform 2]: Cytoplasm': 134,
#  'Photoreceptor inner segment': 34,
#  '[Isoform 1]: Cytoplasm': 88,
#  '[Adhesion G protein-coupled receptor E5 subunit alpha]: Secreted': 1,
#  '[Prostaglandin E synthase 2 truncated form]: Cytoplasm': 1,
#  '[Isoform 3]: Mitochondrion intermembrane space': 1,
#  '[Isoform 4]: Mitochondrion': 3,
#  '[Isoform 5]: Cytoplasm': 29,
#  'Nucleus inner membrane': 38,
#  '[Isoform Long]: Golgi apparatus': 1,
#  '[Isoform Short]: Golgi apparatus': 1,
#  '[Processed beta-1,4-galactosyltransferase 1]: Secreted': 1,
#  '[Isoform 1]: Cell membrane': 114,
#  '[Isoform 4]: Secreted': 19,
#  '[Isoform 6]: Apical cell membrane': 1,
#  '[Isoform 1]: Secreted': 31,
#  '[Isoform 2]: Cell membrane': 54,
#  '[Isoform 3]: Cell membrane': 27,
#  'Virion': 4,
#  '[Surface protein]: Cell membrane': 2,
#  '[Transmembrane protein]: Cell membrane': 3,
#  '[Isoform Gamma]: Cytoplasm': 4,
#  'Basal cell membrane': 13,
#  'Cytolytic granule membrane': 4,
#  '[Isoform Mitochondrial]: Mitochondrion': 6,
#  '[Isoform Cytoplasmic]: Cytoplasm': 5,
#  '[Isoform 1]: Cytoplasmic vesicle': 7,
#  '[Isoform 2]: Secreted': 74,
#  '[Isoform 1]: Apical cell membrane': 5,
#  '[Soluble protein amnionless]: Secreted': 1,
#  '[Isoform Bcl-X(L)]: Mitochondrion inner membrane': 1,
#  '[Isoform 10]: Cell membrane': 1,
#  '[Isoform 6]: Cytoplasm': 20,
#  '[Isoform 7]: Cytoplasm': 11,
#  '[Isoform A2]: Nucleus': 1,
#  '[Isoform 11]: Nucleus': 2,
#  '[Isoform 14]: Nucleus': 1,
#  '[Isoform 12]: Cytoplasm': 3,
#  '[Isoform 1]: Membrane': 19,
#  'Cornified envelope': 2,
#  'Microtubule ends': 6,
#  '[Isoform Alpha]: Cell membrane': 3,
#  '[Isoform Delta]: Cell membrane': 2,
#  '[Isoform Gamma]: Secreted': 3,
#  '[Calcium-activated chloride channel regulator 2, 109 kDa form]: Secreted': 1,
#  'Postsynaptic density membrane': 25,
#  '[Isoform 8]: Cell junction': 2,
#  '[Isoform 5]: Secreted': 13,
#  '[Isoform 1]: Cytoplasmic vesicle membrane': 1,
#  '[Macrophage-expressed gene 1 protein, processed form]: Cytoplasmic vesicle': 1,
#  '[Notch 3 intracellular domain]: Nucleus': 1,
#  'Rough endoplasmic reticulum membrane': 8,
#  '[Latency-associated peptide]: Secreted': 3,
#  '[Transforming growth factor beta-1]: Secreted': 1,
#  'Target cell membrane': 1,
#  'Endosomes': 17,
#  'Lysosomes': 19,
#  '[Small ribosomal subunit protein eS30]: Cytoplasm': 1,
#  'Presynaptic active zone': 7,
#  'Aggresome': 19,
#  'Preautophagosomal structure membrane': 12,
#  '[Isoform DeltaLf]: Cytoplasm': 1,
#  'Nucleus intermembrane space': 1,
#  '[Transmembrane protease serine 11E catalytic chain]: Secreted': 1,
#  '[Isoform 1]: Mitochondrion': 19,
#  '[Isoform C]: Cytoplasm': 1,
#  '[Isoform 1]: Golgi apparatus membrane': 7,
#  '[Isoform 2]: Mitochondrion membrane': 4,
#  '[Isoform 2]: Synapse': 1,
#  '[Isoform 4]: Nucleus': 13,
#  '[Transforming growth factor beta-2]: Secreted': 1,
#  'Rough endoplasmic reticulum lumen': 1,
#  'Golgi apparatus lumen': 5,
#  'Endosome lumen': 4,
#  'Sarcoplasmic reticulum membrane': 29,
#  '[120 kDa linear IgA disease antigen]: Secreted': 1,
#  '[97 kDa linear IgA disease antigen]: Secreted': 1,
#  '[Isoform 5]: Cell membrane': 9,
#  '[Soluble KIT ligand]: Secreted': 1,
#  'Cytoplasmic granule membrane': 8,
#  '[Isoform 1]: Cell projection': 2,
#  '[Isoform 1]: Mitochondrion inner membrane': 8,
#  '[Isoform 2]: Mitochondrion': 9,
#  'Golgi outpost': 4,
#  '[Isoform 1]: Endoplasmic reticulum': 6,
#  '[Isoform 5]: Cell surface': 1,
#  '[Isoform TIAF1]: Nucleus': 1,
#  '[Tumor necrosis factor, membrane form]: Membrane': 1,
#  '[Tumor necrosis factor, soluble form]: Secreted': 1,
#  '[C-domain 1]: Secreted': 1,
#  '[C-domain 2]: Secreted': 1,
#  '[Isoform PRMT2Alpha]: Nucleus': 1,
#  '[Isoform PRMT2Beta]: Cytoplasm': 1,
#  '[Isoform PRMT2Gamma]: Nucleus': 1,
#  '[Isoform PRMT2L2]: Cytoplasm': 1,
#  '[Isoform 4]: Cytoplasm': 37,
#  '[Isoform 2]: Membrane': 10,
#  '[Isoform 4]: Membrane': 4,
#  'Dynein axonemal particle': 20,
#  '[Isoform 5]: Mitochondrion': 3,
#  '[X-box-binding protein 1, cytoplasmic form]: Cytoplasm': 1,
#  'Smooth endoplasmic reticulum membrane': 5,
#  '[Isoform 2]: Endomembrane system': 3,
#  'Sarcoplasmic reticulum': 16,
#  '[Fibrillin-1]: Secreted': 1,
#  '[Asprosin]: Secreted': 1,
#  'Microsome': 18,
#  '[Isoform 6]: Secreted': 9,
#  '[Isoform 7]: Secreted': 6,
#  '[Isoform 10]: Secreted': 3,
#  '[Zona pellucida-like domain-containing protein 1]: Cytoplasmic vesicle membrane': 1,
#  '[Zona pellucida-like domain-containing protein 1, secreted form]: Secreted': 1,
#  '[Isoform 1]: Mitochondrion outer membrane': 1,
#  '[Ceroid-lipofuscinosis neuronal protein 5, secreted form]: Lysosome': 1,
#  '[Ceroid-lipofuscinosis neuronal protein 5]: Membrane': 1,
#  '[Isoform 2B]: Cell membrane': 1,
#  '[Sphingomyelin phosphodiesterase, processed form]: Secreted': 1,
#  'Sarcoplasmic reticulum lumen': 8,
#  'Rods & Rings': 19,
#  '[Isoform FENMIT]: Mitochondrion': 1,
#  '[Isoform 9]: Cell membrane': 2,
#  '[Isoform 11]: Cell membrane': 1,
#  '[Isoform 8]: Secreted': 4,
#  '[Isoform 12]: Secreted': 2,
#  '[Alpha-1,3-mannosyl-glycoprotein 4-beta-N- acetylglucosaminyltransferase A]: Golgi apparatus membrane': 1,
#  '[Alpha-1,3-mannosyl-glycoprotein 4-beta-N- acetylglucosaminyltransferase A soluble form]: Secreted': 1,
#  '[Isoform 2]: Golgi apparatus': 4,
#  '[Heparin-binding EGF-like growth factor]: Secreted': 1,
#  '[Proheparin-binding EGF-like growth factor]: Cell membrane': 1,
#  '[Isoform 1]: Endoplasmic reticulum membrane': 16,
#  'Synaptic cleft': 3,
#  'Synaptic cell membrane': 6,
#  'Peroxisome matrix': 8,
#  '[Isoform ATE1-1]: Nucleus': 1,
#  '[Isoform ATE1-2]: Cytoplasm': 1,
#  '[Beclin-1-C 35 kDa]: Mitochondrion': 1,
#  '[Beclin-1-C 37 kDa]: Mitochondrion': 1,
#  '[DNA-(apurinic or apyrimidinic site) endonuclease, mitochondrial]: Mitochondrion': 1,
#  '[Poly [ADP-ribose] polymerase 1, processed N- terminus]: Chromosome': 1,
#  '[Poly [ADP-ribose] polymerase 1, processed C- terminus]: Cytoplasm': 1,
#  '[Ephrin-A1, secreted form]: Secreted': 1,
#  '[Isoform 1]: Lysosome membrane': 2,
#  '[Isoform 2]: Lysosome membrane': 2,
#  '[Isoform 4]: Golgi apparatus': 2,
#  '[Soluble interleukin-6 receptor subunit alpha]: Secreted': 1,
#  '[Secreted glypican-1]: Secreted': 1,
#  '[Processed cyclic AMP-responsive element-binding protein 3-like protein 4]: Nucleus': 1,
#  '[Isoform USP25m]: Cytoplasm': 1,
#  '[Isoform L-CaBP1]: Cytoplasm': 1,
#  '[Isoform S-CaBP1]: Cytoplasm': 1,
#  '[Isoform 2]: Golgi apparatus membrane': 6,
#  'Photoreceptor outer segment membrane': 6,
#  'Photoreceptor inner segment membrane': 4,
#  '[Gliomedin shedded ectodomain]: Secreted': 1,
#  '[CD43 cytoplasmic tail]: Nucleus': 1,
#  '[Isoform 1]: Lipid droplet': 1,
#  'Preautophagosomal structure': 12,
#  '[Sterol regulatory element-binding protein 1]: Endoplasmic reticulum membrane': 1,
#  '[Processed sterol regulatory element-binding protein 1]: Nucleus': 1,
#  '[Isoform SREBP-1aDelta]: Nucleus': 1,
#  '[Isoform SREBP-1cDelta]: Nucleus': 1,
#  '[Isoform 1]: Mitochondrion membrane': 4,
#  '[Isoform 3]: Mitochondrion membrane': 3,
#  '[Isoform 5]: Mitochondrion membrane': 1,
#  '[Isoform 7]: Mitochondrion membrane': 1,
#  '[Isoform 8]: Cytoplasm': 3,
#  '[Isoform 9]: Cytoplasm': 5,
#  'Vacuole': 1,
#  'Cytoplasmic granule lumen': 2,
#  '[Isoform 2]: Peroxisome matrix': 1,
#  '[Isoform B]: Chromosome': 1,
#  'Extracellular vesicle': 4,
#  '[Megakaryocyte-potentiating factor]: Secreted': 1,
#  '[Isoform 6]: Cell membrane': 6,
#  '[Isoform Alpha]: Lateral cell membrane': 1,
#  '[Isoform Beta]: Apical cell membrane': 1,
#  'Vacuole membrane': 3,
#  '[Podoplanin]: Membrane': 1,
#  '[29kDa cytosolic podoplanin intracellular domain]: Cytoplasm': 1,
#  '[Thrombospondin type-1 domain-containing protein 7A]: Cell membrane': 1,
#  '[Thrombospondin type-1 domain-containing protein 7A, soluble form]: Secreted': 1,
#  '[Ephrin-B1 C-terminal fragment]: Cell membrane': 1,
#  '[Ephrin-B1 intracellular domain]: Nucleus': 1,
#  '[Chondromodulin-1]: Secreted': 1,
#  '[Chondrosurfactant protein]: Endomembrane system': 1,
#  '[Secreted alpha-1,6-mannosylglycoprotein 6-beta- N-acetylglucosaminyltransferase A]: Secreted': 1,
#  'Vesicle': 7,
#  '[Isoform Long]: Cell membrane': 7,
#  '[Isoform Delta15]: Cell junction': 1,
#  '[Isoform 7]: Cell membrane': 3,
#  '[Isoform 8]: Cell membrane': 2,
#  '[Tumor necrosis factor ligand superfamily member 11, soluble form]: Secreted': 1,
#  '[Isoform 1]: Mitochondrion matrix': 4,
#  'Nucleus lamina': 5,
#  '[Small ribosomal subunit protein eS31]: Nucleus': 1,
#  '[Ubiquitin]: Cytoplasm': 4,
#  "[Isoform PSMA']: Cytoplasm": 1,
#  '[Isoform 1]: Early endosome membrane': 2,
#  '[Isoform PACE4A-I]: Secreted': 1,
#  '[Isoform PACE4A-II]: Secreted': 1,
#  '[Isoform PACE4C]: Endoplasmic reticulum': 1,
#  '[Isoform PACE4CS]: Endoplasmic reticulum': 1,
#  '[Isoform PACE4E-I]: Endomembrane system': 1,
#  '[Isoform PACE4E-II]: Endomembrane system': 1,
#  '[Isoform PACE4B]: Secreted': 1,
#  '[Isoform a]: Nucleus': 1,
#  '[Isoform b]: Cytoplasm': 1,
#  'Zymogen granule': 1,
#  '[Isoform IIC4]: Cytoplasm': 1,
#  '[Isoform IIC3]: Cell membrane': 1,
#  '[Isoform IIC2]: Cell membrane': 1,
#  '[Isoform IIC1]: Cell membrane': 1,
#  '[Endoplasmic reticulum membrane sensor NFE2L1]: Endoplasmic reticulum membrane': 1,
#  '[Transcription factor NRF1]: Nucleus': 1,
#  '[Isoform 7]: Nucleus': 3,
#  '[Isoform 8]: Nucleus': 2,
#  '[N-VEGF]: Cytoplasm': 1,
#  '[VEGFA]: Secreted': 1,
#  '[Isoform L-VEGF189]: Endoplasmic reticulum': 1,
#  '[Isoform VEGF121]: Secreted': 1,
#  '[Isoform VEGF165]: Secreted': 1,
#  '[Isoform VEGF189]: Secreted': 1,
#  '[Isoform 10]: Nucleus': 2,
#  '[Ten-1 intracellular domain]: Nucleus': 1,
#  '[Teneurin C-terminal-associated peptide]: Nucleus': 1,
#  '[Isoform p41]: Late endosome': 1,
#  '[Isoform 1]: Lysosome': 2,
#  '[Glucagon-like peptide 1]: Secreted': 1,
#  '[Protein XRCC4, C-terminus]: Cytoplasm': 1,
#  '[Tumor necrosis factor ligand superfamily member 15, secreted form]: Secreted': 1,
#  '[Transforming growth factor beta-3]: Secreted': 1,
#  '[Frataxin mature form]: Mitochondrion': 1,
#  '[Extramitochondrial frataxin]: Cytoplasm': 1,
#  '[Soluble form of JAM-C]: Secreted': 1,
#  '[Isoform 3]: Mitochondrion outer membrane': 2,
#  '[Isoform GFRalpha4a]: Cell membrane': 1,
#  '[Isoform GFRalpha4b]: Cell membrane': 1,
#  '[Isoform GFRalpha4c]: Secreted': 1,
#  '[Processed cyclic AMP-responsive element-binding protein 3-like protein 3]: Nucleus': 1,
#  '[Isoform 1]: Golgi apparatus lumen': 1,
#  '[Isoform 1]: Peroxisome': 2,
#  '[Protocadherin Fat 1]: Cell membrane': 1,
#  '[Protocadherin Fat 1, nuclear form]: Nucleus': 1,
#  '[Isoform EPOR-S]: Secreted': 1,
#  '[Isoform 2]: Mitochondrion inner membrane': 5,
#  '[Isoform PDE7A1]: Cytoplasm': 1,
#  '[Isoform PDE7A2]: Cytoplasm': 1,
#  '[Enhancer of filamentation 1 p55]: Cytoplasm': 1,
#  'Extracellular vesicle membrane': 6,
#  '[Isoform IFI16-beta]: Cytoplasm': 1,
#  '[Isoform 1]: Basolateral cell membrane': 2,
#  '[Isoform 2]: Apical cell membrane': 2,
#  '[DAP3-binding cell death enhancer 1]: Mitochondrion': 1,
#  '[DAP3-binding cell death enhancer 1 short form]: Cytoplasm': 1,
#  '[Isoform SCP2]: Peroxisome': 1,
#  '[Isoform SCPx]: Peroxisome': 1,
#  '[Isoform 2]: Cytoplasmic vesicle membrane': 1,
#  '[Phosphatidylserine decarboxylase beta chain]: Mitochondrion inner membrane': 1,
#  '[Phosphatidylserine decarboxylase alpha chain]: Mitochondrion inner membrane': 1,
#  '[A20p50]: Cytoplasm': 1,
#  '[Ninjurin-1]: Cell membrane': 1,
#  '[Secreted ninjurin-1]: Secreted': 1,
#  '[C30]: Cytoplasm': 1,
#  '[Junctophilin-2]: Cell membrane': 1,
#  '[Junctophilin-2 N-terminal fragment]: Nucleus': 1,
#  '[Isoform 5]: Endomembrane system': 1,
#  '[Isoform 3]: Membrane': 4,
#  'Apicolateral cell membrane': 3,
#  '[Polymeric immunoglobulin receptor]: Cell membrane': 1,
#  '[Secretory component]: Secreted': 1,
#  '[Isoform Sp100-C]: Nucleus': 1,
#  '[Fibrillin-2]: Secreted': 1,
#  '[Placensin]: Secreted': 1,
#  'Kinetochore': 6,
#  '[Isoform NKp44L]: Cytoplasm': 1,
#  '[Glutaminase kidney isoform, mitochondrial 68 kDa chain]: Mitochondrion matrix': 1,
#  '[Glutaminase kidney isoform, mitochondrial 65 kDa chain]: Mitochondrion matrix': 1,
#  'Inflammasome': 10,
#  '[Endogenous retroviral envelope protein HEMO]: Cell membrane': 1,
#  '[Endogenous retroviral envelope protein HEMO, secreted form]: Secreted': 1,
#  '[Isoform A]: Endoplasmic reticulum membrane': 1,
#  '[Isoform B]: Endoplasmic reticulum membrane': 1,
#  '[Isoform C]: Endoplasmic reticulum membrane': 1,
#  '[Isoform smARF]: Mitochondrion': 1,
#  '[Isoform 5]: Endoplasmic reticulum': 1,
#  '[Isoform 5]: Cytoplasmic vesicle': 2,
#  '[Isoform 9]: Nucleus': 2,
#  '[Isoform 12]: Nucleus': 1,
#  'Zymogen granule membrane': 8,
#  '[Isoform Alpha]: Secreted': 1,
#  '[Isoform Beta]: Microsome membrane': 1,
#  '[Lymphocyte activation gene 3 protein]: Cell membrane': 1,
#  '[Secreted lymphocyte activation gene 3 protein]: Secreted': 1,
#  '[Isoform 1]: Nucleus speckle': 3,
#  '[Isoform 3]: Nucleus speckle': 1,
#  '[Isoform Ik2]: Nucleus': 1,
#  '[Isoform Ik6]: Cytoplasm': 1,
#  '[Isoform 13]: Secreted': 1,
#  '[Tumor necrosis factor ligand superfamily member 13b, soluble form]: Secreted': 1,
#  '[ADGRG1 N-terminal fragment]: Secreted': 1,
#  '[ADGRG1 C-terminal fragment]: Membrane raft': 1,
#  '[Isoform 1]: Perikaryon': 1,
#  '[Isoform 2]: Nucleus membrane': 1,
#  '[Xenin]: Secreted': 1,
#  '[Soluble secretory phospholipase A2 receptor]: Secreted': 1,
#  '[Isoform 5]: Membrane': 2,
#  '[Isoform I-214]: Nucleus': 1,
#  '[Isoform I-245]: Nucleus': 1,
#  '[Isoform 2]: Perikaryon': 1,
#  '[Neurosecretory protein VGF]: Secreted': 1,
#  '[Uromodulin, secreted form]: Secreted': 1,
#  '[Adipolin fC1QTNF12]: Secreted': 1,
#  '[Adipolin gC1QTNF12]: Secreted': 1,
#  '[Bone marrow proteoglycan]: Secreted': 1,
#  '[Eosinophil granule major basic protein]: Cytoplasmic vesicle': 1,
#  '[Secreted glypican-4]: Secreted': 1,
#  '[Gasdermin-E, N-terminal]: Cell membrane': 1,
#  '[Gasdermin-E]: Cytoplasm': 1,
#  '[Isoform 1]: Golgi apparatus': 3,
#  '[Isoform 4]: Endoplasmic reticulum': 3,
#  '[Isoform 6]: Endoplasmic reticulum': 1,
#  '[Myelin regulatory factor]: Endoplasmic reticulum membrane': 1,
#  '[Myelin regulatory factor, N-terminal]: Nucleus': 1,
#  '[Myelin regulatory factor, C-terminal]: Endoplasmic reticulum membrane': 1,
#  '[Processed PDZ domain-containing protein 2]: Secreted': 1,
#  '[Notch 2 extracellular truncation]: Cell membrane': 1,
#  '[Notch 2 intracellular domain]: Nucleus': 1,
#  '[Isoform 2]: Late endosome membrane': 1,
#  '[Isoform A]: Apical cell membrane': 2,
#  '[Isoform B1]: Apical cell membrane': 1,
#  '[Isoform B2]: Apical cell membrane': 1,
#  '[Isoform Beta-1]: Nucleus': 1,
#  '[Isoform Beta-2]: Nucleus': 1,
#  '[Isoform Beta-4]: Cytoplasm': 1,
#  '[Isoform IL15-S48AA]: Secreted': 1,
#  '[Isoform IL15-S21AA]: Cytoplasm': 1,
#  '[Isoform Soluble]: Cytoplasm': 1,
#  '[Isoform Membrane-bound]: Cell membrane': 1,
#  '[Isoform CD33M]: Cell membrane': 1,
#  '[Isoform CD33m]: Peroxisome': 1,
#  '[Isoform Alpha]: Cell junction': 1,
#  '[Isoform Beta]: Cell junction': 1,
#  '[Isoform Short]: Secreted': 4,
#  '[Transmembrane protease serine 2 catalytic chain]: Secreted': 1,
#  '[Isoform A]: Nucleus': 2,
#  '[Isoform 4]: Mitochondrion outer membrane': 1,
#  '[Processed zona pellucida sperm-binding protein 4]: Zona pellucida': 1,
#  '[Histatin-1]: Secreted': 1,
#  '[His1-(31-57)-peptide]: Secreted': 1,
#  '[Isoform 1]: Mitochondrion intermembrane space': 1,
#  '[Isoform 4]: Nucleus envelope': 1,
#  '[Isoform 1]: Endosome membrane': 1,
#  '[Protein SLFN14]: Nucleus': 1,
#  '[Isoform CLSTN3beta]: Lipid droplet': 1,
#  '[Isoform 2]: Endosome membrane': 1,
#  '[Isoform 9]: Secreted': 3,
#  '[Isoform 11]: Secreted': 2,
#  '[IA-2beta60]: Cytoplasmic vesicle': 1,
#  '[Isoform 5a]: Nucleus': 1,
#  '[Isoform I]: Cell membrane': 1,
#  '[Isoform II]: Secreted': 1,
#  '[Matrix metalloproteinase-24]: Cell membrane': 1,
#  '[Processed matrix metalloproteinase-24]: Secreted': 1,
#  '[Pro-neuregulin-4, membrane-bound isoform]: Cell membrane': 1,
#  '[Neuregulin-4]: Secreted': 1,
#  '[Neutral ceramidase]: Cell membrane': 1,
#  '[Neutral ceramidase soluble form]: Secreted': 1,
#  '[CD160 antigen]: Cell membrane': 1,
#  '[CD160 antigen, soluble form]: Secreted': 1,
#  '[C-terminal 80 kDa form]: Secreted': 1,
#  '[Isoform C]: Nucleus speckle': 1,
#  'Myelin membrane': 3,
#  '[Protocadherin-12]: Cell membrane': 1,
#  '[Protocadherin-12, secreted form]: Secreted': 1,
#  '[Isoform LIMK2a]: Cytoplasm': 1,
#  '[Isoform LIMK2b]: Cytoplasm': 1,
#  '[Notch 4 intracellular domain]: Nucleus': 1,
#  '[C-terminal domain]: Nucleus': 1,
#  '[Soluble HLA class I histocompatibility antigen, alpha chain E]: Secreted': 1,
#  '[Isoform IB]: Nucleus membrane': 1,
#  '[Isoform SOFAT]: Secreted': 1,
#  '[Processed cyclic AMP-responsive element-binding protein 3]: Nucleus': 1,
#  '[Gasdermin-C]: Cytoplasm': 1,
#  '[Gasdermin-C, N-terminal]: Cell membrane': 1,
#  '[Isoform 1]: Peroxisome membrane': 1,
#  '[Isoform MBP-1]: Nucleus': 1,
#  '[Isoform E]: Endoplasmic reticulum': 1,
#  '[Isoform D]: Endoplasmic reticulum': 1,
#  '[Isoform B]: Cell membrane': 1,
#  '[Isoform A]: Cell membrane': 1,
#  '[POLG alternative reading frame]: Nucleus': 1,
#  '[POLGARF C-terminal fragment]: Secreted': 1,
#  '[Isoform T]: Nucleus': 1,
#  '[Isoform H]: Cell membrane': 1,
#  '[Cysteine protease ATG4D]: Cytoplasm': 1,
#  '[Cysteine protease ATG4D, mitochondrial]: Cytoplasm': 1,
#  '[Isoform 2]: Mitochondrion outer membrane': 1,
#  '[Huntingtin]: Cytoplasm': 1,
#  '[Huntingtin, myristoylated N-terminal fragment]: Cytoplasmic vesicle': 1,
#  '[Prolyl endopeptidase FAP]: Cell surface': 1,
#  '[Antiplasmin-cleaving enzyme FAP, soluble form]: Secreted': 1,
#  '[NT-proBNP]: Secreted': 1,
#  '[proBNP(3-108)]: Secreted': 1,
#  '[Brain natriuretic peptide 32]: Secreted': 1,
#  '[BNP(3-32)]: Secreted': 1,
#  '[MAP1 light chain LC1]: Cytoplasm': 1,
#  '[Gasdermin-A]: Cytoplasm': 1,
#  '[Gasdermin-A, N-terminal]: Cell membrane': 1,
#  '[Isoform Alpha]: Cytoplasm': 3,
#  '[Isoform Beta]: Cytoplasm': 3,
#  '[Isoform Gamma]: Nucleus': 1,
#  '[Isoform PDE4B5]: Cytoplasm': 1,
#  '[Serpinin]: Secreted': 1,
#  '[Ten-2 intracellular domain]: Nucleus': 1,
#  '[Isoform 5]: Nucleus': 4,
#  '[T-cell surface glycoprotein CD1e, membrane- associated]: Golgi apparatus membrane': 1,
#  '[T-cell surface glycoprotein CD1e, soluble]: Lysosome lumen': 1,
#  '[Sterol regulatory element-binding protein 2]: Endoplasmic reticulum membrane': 1,
#  '[Processed sterol regulatory element-binding protein 2]: Nucleus': 1,
#  'Zymogen granule lumen': 3,
#  '[Isoform B]: Cytoplasm': 2,
#  '[Klotho peptide]: Secreted': 1,
#  '[Isoform 2]: Basolateral cell membrane': 1,
#  '[Polypeptide N-acetylgalactosaminyltransferase 1]: Golgi apparatus': 1,
#  '[Polypeptide N-acetylgalactosaminyltransferase 1 soluble form]: Secreted': 1,
#  '[Isoform 3]: Endoplasmic reticulum': 1,
#  '[Prosaposin]: Secreted': 1,
#  '[Isoform IRGMd]: Mitochondrion': 1,
#  '[Rhomboid-related protein 2, C-terminal fragment]: Cell membrane': 1,
#  '[Myocilin, C-terminal fragment]: Secreted': 1,
#  '[Myocilin, N-terminal fragment]: Endoplasmic reticulum': 1,
#  '[MLL cleavage product N320]: Nucleus': 1,
#  '[MLL cleavage product C180]: Nucleus': 1,
#  '[Isoform 6]: Nucleus': 3,
#  '[Processed kin of IRRE-like protein 3]: Secreted': 1,
#  '[Isoform 2]: Lipid droplet': 1,
#  '[Isoform 1]: Cell junction': 1,
#  '[Isoform Zeta]: Cytoplasm': 1,
#  '[Isoform BimEL]: Mitochondrion': 1,
#  '[Isoform BimL]: Mitochondrion': 1,
#  '[Isoform BimS]: Mitochondrion': 1,
#  '[Isoform Bim-alpha1]: Mitochondrion': 1,
#  '[Soluble HLA class I histocompatibility antigen, alpha chain G]: Secreted': 1,
#  '[Extracellular sulfatase Sulf-2 secreted form]: Secreted': 2,
#  '[Isoform p46Shc]: Mitochondrion matrix': 1,
#  '[Isoform p66Shc]: Mitochondrion': 1,
#  '[CD40 ligand, soluble form]: Secreted': 1,
#  '[Non-collagenous domain 1]: Secreted': 1,
#  '[Endostatin]: Secreted': 1,
#  '[Isoform 3]: Endoplasmic reticulum membrane': 2,
#  '[Low-density lipoprotein receptor-related protein 1 85 kDa subunit]: Cell membrane': 1,
#  '[Low-density lipoprotein receptor-related protein 1 515 kDa subunit]: Cell membrane': 1,
#  '[Low-density lipoprotein receptor-related protein 1 intracellular domain]: Cytoplasm': 1,
#  '[Isoform 4]: Mitochondrion matrix': 1,
#  '[Transferrin receptor protein 1, serum form]: Secreted': 1,
#  '[Indian hedgehog protein N-product]: Cell membrane': 1,
#  '[Indian hedgehog protein]: Endoplasmic reticulum membrane': 1,
#  '[Isoform p18]: Cytoplasm': 1,
#  '[Isoform p26]: Mitochondrion matrix': 1,
#  '[Isoform PDE9A1]: Cell projection': 1,
#  '[Isoform PDE9A2]: Cell projection': 1,
#  '[Isoform PDE9A3]: Cytoplasm': 1,
#  '[Isoform PDE9A17]: Cytoplasm': 1,
#  '[Peptide Lv]: Secreted': 1,
#  '[Caspase recruitment domain-containing protein 8, C-terminus]: Inflammasome': 1,
#  '[Betacellulin]: Secreted': 1,
#  '[Probetacellulin]: Cell membrane': 1,
#  '[Large ribosomal subunit protein eL40]: Cytoplasm': 1,
#  '[Soluble dopamine beta-hydroxylase]: Cytoplasmic vesicle': 1,
#  '[NACHT, LRR and PYD domains-containing protein 1, C-terminus]: Inflammasome': 1,
#  '[NACHT, LRR and PYD domains-containing protein 1, N-terminus]: Nucleus': 1,
#  '[Isoform H1a]: Membrane': 1,
#  '[Isoform H1b]: Secreted': 1,
#  '[ICA512-transmembrane fragment]: Cytoplasmic vesicle': 1,
#  '[ICA512-cleaved cytosolic fragment]: Nucleus': 1,
#  '[Isoform 5]: Endoplasmic reticulum membrane': 2,
#  '[Isoform 6]: Endoplasmic reticulum membrane': 1,
#  '[Isoform 7]: Endoplasmic reticulum membrane': 1,
#  '[Isoform 8]: Endoplasmic reticulum membrane': 2,
#  '[Soluble interleukin-15 receptor subunit alpha]: Secreted': 1,
#  '[Long-acting natriuretic peptide]: Secreted': 1,
#  '[Vessel dilator]: Secreted': 1,
#  '[Kaliuretic peptide]: Secreted': 1,
#  '[Urodilatin]: Secreted': 1,
#  '[Atrial natriuretic peptide]: Secreted': 1,
#  '[Atriopeptin-3]: Secreted': 1,
#  '[Processed angiotensin-converting enzyme 2]: Secreted': 1,
#  '[Ectonucleotide pyrophosphatase/phosphodiesterase family member 1]: Cell membrane': 1,
#  '[Ectonucleotide pyrophosphatase/phosphodiesterase family member 1, secreted form]: Secreted': 1,
#  '[Tumor necrosis factor-binding protein 2]: Secreted': 1,
#  '[Isoform Er1]: Cytoplasm': 1,
#  '[Isoform Mu17]: Membrane': 1,
#  '[Isoform Mu18]: Sarcoplasmic reticulum': 1,
#  '[Isoform Mu19]: Sarcoplasmic reticulum': 1,
#  '[Isoform Mu20]: Sarcoplasmic reticulum': 1,
#  '[Pro-neuregulin-2, membrane-bound isoform]: Cell membrane': 1,
#  '[Neuregulin-2]: Secreted': 1,
#  '[Processed fractalkine]: Secreted': 1,
#  '[Tumor necrosis factor ligand superfamily member 6, soluble form]: Secreted': 1,
#  '[FasL intracellular domain]: Nucleus': 1,
#  '[Isoform BIN1]: Nucleus': 1,
#  '[Isoform IIA]: Cytoplasm': 1,
#  '[Isoform PDE2A3]: Cell membrane': 1,
#  '[Isoform PDE2A2]: Mitochondrion matrix': 1,
#  '[Isoform PDE2A1]: Cytoplasm': 1,
#  '[Isoform GANP]: Nucleus envelope': 1,
#  '[Isoform MCM3AP]: Cytoplasm': 1,
#  'Autolysosome membrane': 1,
#  '[Isoform Beta]: Secreted': 1,
#  '[PXDN active fragment]: Secreted': 1,
#  '[Isoform L-MPZ]: Myelin membrane': 1,
#  '[Isoform v2]: Endoplasmic reticulum': 1,
#  '[Isoform v5]: Endoplasmic reticulum': 1,
#  '[Processed cysteine-rich motor neuron 1 protein]: Secreted': 1,
#  '[Isoform 3]: Golgi apparatus': 2,
#  '[Gasdermin-D]: Cytoplasm': 1,
#  '[Gasdermin-D, N-terminal]: Cell membrane': 1,
#  '[Gasdermin-D, N-terminal]: Cytoplasm': 1,
#  '[Gasdermin-D, p13]: Nucleus': 1,
#  '[Gasdermin-D, C-terminal]: Cytoplasm': 1,
#  '[Alpha-dystroglycan]: Secreted': 1,
#  '[Beta-dystroglycan]: Cell membrane': 1,
#  '[Isoform 1]: Endoplasmic reticulum lumen': 1,
#  '[Isoform Short]: Cytoplasm': 1,
#  '[Isoform Long]: Nucleus': 1,
#  '[Gasdermin-B]: Cytoplasm': 1,
#  '[Gasdermin-B, N-terminal]: Cell membrane': 1,
#  '[Cyclic AMP-responsive element-binding protein 3- like protein 1]: Endoplasmic reticulum membrane': 1,
#  '[Processed cyclic AMP-responsive element-binding protein 3-like protein 1]: Nucleus': 1,
#  '[Soluble Alc-alpha]: Nucleus': 1,
#  '[Isoform alpha]: Secreted': 2,
#  '[Soluble CD163]: Secreted': 1,
#  '[Tumor necrosis factor ligand superfamily member 12, secreted form]: Secreted': 1,
#  '[Isoform TWE-PRIL]: Cell membrane': 1,
#  '[Desert hedgehog protein N-product]: Cell membrane': 1,
#  '[Desert hedgehog protein]: Endoplasmic reticulum membrane': 1,
#  '[Isoform 10]: Cytoplasm': 1,
#  '[Isoform 4]: Mitochondrion inner membrane': 1,
#  '[Serine/threonine-protein kinase PAK 2]: Cytoplasm': 1,
#  '[PAK-2p34]: Nucleus': 1,
#  '[Isoform Kastor]: Mitochondrion outer membrane': 1,
#  '[Isoform Polluks]: Mitochondrion outer membrane': 1,
#  '[Leucyl-cystinyl aminopeptidase, pregnancy serum form]: Secreted': 1,
#  '[Isoform Alpha]: Mitochondrion outer membrane': 1,
#  '[Isoform Delta]: Cytoplasm': 2,
#  '[Processed macrophage colony-stimulating factor 1]: Secreted': 1,
#  '[Isoform ARTS]: Mitochondrion': 1,
#  '[Integral membrane protein 2B]: Golgi apparatus membrane': 1,
#  '[BRI2, membrane form]: Cell membrane': 1,
#  '[Bri23 peptide]: Secreted': 1,
#  '[BRI2C, soluble form]: Secreted': 1,
#  '[Isoform PMR1]: Cytoplasm': 1,
#  '[Survival-promoting peptide]: Secreted': 1,
#  '[DCD-1]: Secreted': 1,
#  '[Isoform BMP1-3]: Secreted': 1,
#  '[Transmembrane protease serine 11D catalytic chain]: Secreted': 1,
#  '[iHOPS]: Cytoplasm': 1,
#  '[Isoform 13]: Cytoplasm': 1,
#  '[Isoform A]: Nucleus matrix': 1,
#  '[Alpha-1-microglobulin]: Secreted': 1,
#  '[Inter-alpha-trypsin inhibitor light chain]: Secreted': 1,
#  '[Interleukin-11 receptor subunit alpha]: Membrane': 1,
#  '[Soluble interleukin-11 receptor subunit alpha]: Secreted': 1,
#  '[Isoform HCR2]: Secreted': 1,
#  '[Ectodysplasin-A, secreted form]: Secreted': 1,
#  '[Isoform 2]: Mitochondrion matrix': 2,
#  '[Isoform Beta]: Nucleus': 2,
#  '[Atrial natriuretic peptide-converting enzyme, 180 kDa soluble fragment]: Secreted': 1,
#  '[Atrial natriuretic peptide-converting enzyme, 160 kDa soluble fragment]: Secreted': 1,
#  '[Atrial natriuretic peptide-converting enzyme, 100 kDa soluble fragment]: Secreted': 1,
#  '[Isoform a]: Cytoplasm': 1,
#  '[Isoform 2]: Cell projection': 2,
#  '[Isoform Y]: Secreted': 1,
#  '[Mucin-1 subunit beta]: Cell membrane': 1,
#  '[Isoform 2]: Postsynaptic density': 1,
#  '[Tumor necrosis factor ligand superfamily member 14, membrane form]: Cell membrane': 1,
#  '[Tumor necrosis factor ligand superfamily member 14, soluble form]: Secreted': 1,
#  '[Processed poliovirus receptor-related protein 4]: Secreted': 1,
#  '[Isoform Alpha-2]: Cytoplasm': 1,
#  '[Isoform E]: Secreted': 1,
#  'Cytoplasmic vesicle lumen': 2,
#  '[Double-strand-break repair protein rad21 homolog]: Nucleus': 1,
#  '[64-kDa C-terminal product]: Cytoplasm': 1,
#  '[Nesfatin-1]: Secreted': 1,
#  '[Isoform 2]: Early endosome membrane': 1,
#  '[Isoform 4]: Sarcoplasmic reticulum membrane': 1,
#  '[SirtT1 75 kDa fragment]: Cytoplasm': 1,
#  '[Isoform 1A]: Nucleus': 2,
#  '[Isoform 2A]: Mitochondrion': 1,
#  '[Vascular cell adhesion protein 1]: Cell membrane': 1,
#  '[Soluble Vascular Cell Adhesion Molecule-1]: Secreted': 1,
#  '[Isoform 3]: Cytoplasmic vesicle': 1,
#  '[Isoform 4]: Cytoplasmic vesicle': 1,
#  '[Interleukin-16]: Secreted': 1,
#  '[Secreted glypican-6]: Secreted': 1,
#  '[Isoform s9]: Secreted': 1,
#  '[Isoform CAE3]: Cell membrane': 1,
#  '[Secreted glypican-2]: Secreted': 1,
#  '[Isoform 1]: Nucleus matrix': 2,
#  '[Isoform 7]: Membrane': 1,
#  '[Isoform 1E]: Secreted': 1,
#  '[Isoform A1]: Cell junction': 1,
#  '[Isoform A2]: Cell junction': 1,
#  '[BDNF precursor form]: Secreted': 1,
#  '[Pro-neuregulin-3, membrane-bound isoform]: Cell membrane': 1,
#  '[Neuregulin-3]: Secreted': 1,
#  '[N-acetylglucosamine-1-phosphotransferase subunit alpha]: Golgi apparatus membrane': 1,
#  '[N-acetylglucosamine-1-phosphotransferase subunit beta]: Golgi apparatus membrane': 1,
#  '[Isoform Cytoplasmic+peroxisomal]: Cytoplasm': 1,
#  'Postsynaptic recycling endosome membrane': 2,
#  '[Isoform Short]: Endoplasmic reticulum membrane': 1,
#  '[Isoform gamma]: Endoplasmic reticulum membrane': 1,
#  'Parasitophorous vacuole': 1,
#  '[His3-(20-43)-peptide]: Secreted': 1,
#  '[Iron-sulfur cluster co-chaperone protein HscB, cytoplasmic]: Cytoplasm': 1,
#  '[Iron-sulfur cluster co-chaperone protein HscB, mitochondrial]: Mitochondrion': 1,
#  '[Dipeptidyl peptidase 4 soluble form]: Secreted': 1,
#  '[Processed exostosin-like 2]: Secreted': 1,
#  '[Isoform beta]: Nucleus': 1,
#  '[Isoform gamma]: Nucleus': 1,
#  '[Isoform Alpha-B]: Nucleus': 1,
#  '[Soluble CD6]: Secreted': 1,
#  '[Sonic hedgehog protein]: Endoplasmic reticulum membrane': 1,
#  '[Sonic hedgehog protein N-product]: Cell membrane': 1,
#  '[Cyclin-dependent kinase 5 activator 1, p35]: Cell membrane': 1,
#  '[Cyclin-dependent kinase 5 activator 1, p25]: Nucleus': 1,
#  '[Isoform 4]: Endoplasmic reticulum membrane': 1,
#  '[Isoform 5]: Nucleus matrix': 1,
#  '[Processed zona pellucida sperm-binding protein 1]: Zona pellucida': 1,
#  '[Isoform 3]: Postsynaptic density': 1,
#  '[Processed cyclic AMP-dependent transcription factor ATF-6 beta]: Nucleus': 1,
#  '[Small integral membrane protein 20]: Mitochondrion inner membrane': 1,
#  '[Phoenixin-14]: Secreted': 1,
#  '[Phoenixin-20]: Secreted': 1,
#  '[Isoform 3]: Golgi apparatus membrane': 1,
#  '[Isoform 4]: Golgi apparatus membrane': 1,
#  '[Isoform 5]: Golgi apparatus membrane': 1,
#  '[Vasculostatin-120]: Secreted': 1,
#  '[Vasculostatin-40]: Secreted': 1,
#  '[Short peptide from AAT]: Secreted': 1,
#  '[Isoform QKI5]: Nucleus': 1,
#  '[Isoform QKI6]: Cytoplasm': 1,
#  '[Isoform QKI7]: Cytoplasm': 1,
#  '[Isoform A-1]: Cell membrane': 1,
#  '[Isoform A-2]: Cell membrane': 1,
#  '[Isoform A-3]: Cell membrane': 1,
#  '[Isoform B]: Secreted': 2,
#  '[Isoform B-delta-S2]: Secreted': 1,
#  '[Syncytin-1]: Virion': 1,
#  '[Isoform 2A]: Nucleus': 1,
#  '[Isoform 3A]: Nucleus': 1,
#  '[BH3-interacting domain death agonist p15]: Mitochondrion membrane': 1,
#  '[BH3-interacting domain death agonist p13]: Mitochondrion membrane': 1,
#  '[Nuclear factor NF-kappa-B p105 subunit]: Cytoplasm': 1,
#  '[Nuclear factor NF-kappa-B p50 subunit]: Nucleus': 1,
#  '[Isoform 2]: Cytoplasmic vesicle': 1,
#  '[Isoform RANK-e5a]: Cell membrane': 1,
#  '[Angiotensin-converting enzyme, soluble form]: Secreted': 1,
#  '[Isoform Testis-specific]: Cell membrane': 1,
#  '[Isoform 2]: Peroxisome': 1,
#  '[Growth hormone-binding protein]: Secreted': 1,
#  '[WND/140 kDa]: Mitochondrion': 1,
#  '[Isoform 5]: Mitochondrion matrix': 1,
#  '[Isoform Alpha I]: Nucleus': 1,
#  '[Isoform Alpha II]: Cytoplasm': 1,
#  '[Processed inositol 1,4,5-triphosphate receptor associated 2]: Cytoplasm': 1,
#  '[Epiregulin]: Secreted': 1,
#  '[Proepiregulin]: Cell membrane': 1,
#  '[Processed neural cell adhesion molecule L1-like protein]: Secreted': 1,
#  '[Isoform B4]: Nucleus': 1,
#  '[Isoform B4-8a]: Cytoplasm': 1,
#  '[Isoform B5]: Nucleus': 1,
#  '[C83]: Endoplasmic reticulum': 1,
#  '[C99]: Early endosome': 1,
#  '[Soluble APP-beta]: Secreted': 1,
#  '[Amyloid-beta protein 40]: Cell surface': 1,
#  '[Amyloid-beta protein 42]: Cell surface': 1,
#  '[Gamma-secretase C-terminal fragment 59]: Nucleus': 1,
#  '[Isoform Short]: Cell membrane': 1,
#  '[Isoform Long]: Endosome membrane': 1,
#  '[Pro-neuregulin-1, membrane-bound isoform]: Cell membrane': 1,
#  '[Neuregulin-1]: Secreted': 1,
#  '[Isoform 10]: Membrane': 1,
#  '[Processed zona pellucida sperm-binding protein 3]: Zona pellucida': 1,
#  '[Isoform WA]: Apical cell membrane': 1,
#  '[Isoform WB]: Apical cell membrane': 1,
#  '[Isoform XB]: Basolateral cell membrane': 1,
#  '[Isoform ZA]: Basolateral cell membrane': 1,
#  '[Isoform ZB]: Basolateral cell membrane': 1,
#  '[Isoform M2]: Cytoplasm': 1,
#  '[Isoform M1]: Cytoplasm': 1,
#  '[Processed cyclic AMP-dependent transcription factor ATF-6 alpha]: Nucleus': 1,
#  '[Mucin-4 beta chain]: Cell membrane': 1,
#  '[Mucin-4 alpha chain]: Cell membrane': 1,
#  '[Isoform 15]: Secreted': 1,
#  '[Isoform 17]: Cell membrane': 1,
#  '[ERBB4 intracellular domain]: Nucleus': 1,
#  '[Isoform 2]: Nucleus inner membrane': 1,
#  '[Processed zona pellucida sperm-binding protein 2]: Zona pellucida': 1,
#  '[Transmembrane protease serine 4 catalytic chain]: Secreted': 1,
#  '[Transforming growth factor alpha]: Secreted': 1,
#  '[Protransforming growth factor alpha]: Cell membrane': 1,
#  '[Prostasin]: Cell membrane': 1,
#  '[Prostasin light chain]: Secreted': 1,
#  '[Prostasin heavy chain]: Secreted': 1,
#  '[Isoform GSRP-56]: Golgi apparatus': 1,
#  '[Notch 1 intracellular domain]: Nucleus': 1,
#  '[Secreted glypican-5]: Secreted': 1,
#  '[Isoform PC6A]: Secreted': 1,
#  '[Isoform PC6B]: Endomembrane system': 1,
#  '[Isoform C]: Cell membrane': 1,
#  '[Irisin]: Secreted': 1}

# %%
sl_labels_count
# Out:
# {'Cellular component': 28939,
#  'Nucleus speckle': 486,
#  'Cytosol': 4834,
#  'Nucleolus': 1214,
#  'Nucleoplasm': 6102,
#  'Golgi apparatus': 1154,
#  'Vesicle': 2212,
#  'Nucleolus fibrillar center': 309,
#  'Mitochondrion': 1102,
#  'Cell membrane': 2054,
#  'Focal adhesion': 136,
#  'Nuclear body': 584,
#  'Endoplasmic reticulum': 527,
#  'Cytoskeleton': 500,
#  'Midbody ring': 23,
#  'Cytoplasmic ribonucleoprotein granule': 71,
#  'Nucleus membrane': 272,
#  'Spindle': 92,
#  'Centriolar satellite': 187,
#  'Peroxisome': 23,
#  'Centrosome': 387,
#  'Cell junction': 325,
#  'Nucleus lamina': 162,
#  'Chromosome': 74,
#  'Midbody': 51,
#  'Lipid droplet': 39,
#  'Endosome': 17,
#  'Lysosome': 19,
#  'Kinetochore': 6,
#  'Cleavage furrow': 1}

# %% [markdown]
# ## Question:
# Should I merge all isoforms together in locations?
# Is using "labelSL" counts enough for this project?

# %%
labels = list(sl_labels_count.keys())
counts = list(sl_labels_count.values())

plt.pie(counts, labels=labels, autopct='%1.2f%%')
plt.show()

# %%
df_targets_simplified_exp_locs.groupby("id").sum()
# Out:
#                                                            biotype  \
# id
# ENSG00000000003  protein_codingprotein_codingprotein_codingprot...
# ENSG00000000005  protein_codingprotein_codingprotein_codingprot...
# ENSG00000000419                                     protein_coding
# ENSG00000000457  protein_codingprotein_codingprotein_codingprot...
# ENSG00000000460  protein_codingprotein_codingprotein_codingprot...
# ...                                                            ...
# ENSG00000291237                       protein_codingprotein_coding
# ENSG00000291307                       protein_codingprotein_coding
# ENSG00000291309                                     protein_coding
# ENSG00000291317                                     protein_coding
# ENSG00000293543                                     protein_coding
#
#                 alternativeGenes  \
# id
# ENSG00000000003                0
# ENSG00000000005                0
# ENSG00000000419                0
# ENSG00000000457                0
# ENSG00000000460                0
# ...                          ...
# ENSG00000291237                0
# ENSG00000291307                0
# ENSG00000291309                0
# ENSG00000291317                0
# ENSG00000293543                0
#
#                                               subcellular_location  \
# id
# ENSG00000000003  MembraneCell JunctionsCytosolNucleoli fibrilla...
# ENSG00000000005  [Isoform 1]: MembraneNucleus envelope[Isoform ...
# ENSG00000000419                              Endoplasmic reticulum
# ENSG00000000457  CytoplasmGolgi apparatusCell projectionCytosol...
# ENSG00000000460             ChromosomeMidbodyCytoplasmMitochondria
# ...                                                            ...
# ENSG00000291237                   Mitochondrion matrixMitochondria
# ENSG00000291307  [POLG alternative reading frame]: Nucleus[POLG...
# ENSG00000291309                                      Cell membrane
# ENSG00000291317                                           Membrane
# ENSG00000293543                                          Cytoplasm
#
#                                         subcellular_location_label
# id
# ENSG00000000003  Cellular componentCell junctionCytosolNucleolu...
# ENSG00000000005  Cellular componentCellular componentCellular c...
# ENSG00000000419                                 Cellular component
# ENSG00000000457  Cellular componentCellular componentCellular c...
# ENSG00000000460  Cellular componentCellular componentCellular c...
# ...                                                            ...
# ENSG00000291237                    Cellular componentMitochondrion
# ENSG00000291307               Cellular componentCellular component
# ENSG00000291309                                 Cellular component
# ENSG00000291317                                 Cellular component
# ENSG00000293543                                 Cellular component
#
# [18930 rows x 4 columns]

# %% [markdown]
# ### Question:
# is alternative gene another version of the same gene(hg 19 or 38), or are they separate? Answer: Alternative genes are the different alleles, confirmed by Ensembl database

# %%
df_targets_simplified_exp_locs.groupby("subcellular_location_label")["id"].nunique().plot.pie(autopct='%1.2f%%')
# Out:
# <Axes: ylabel='id'>

# %%
sum(locations_count.values())
# Out:
# 52784

# %%
sum(counts)
# Out:
# 51902

# %%
## Save the processed target data
df_targets_simplified_exp_locs.to_csv("preprocessed_targets.tsv", sep="\t", index=False)"

# %%
## TODO: Combine processed data
## step 1: combine molecules (drugs) to moa
## step 2: combine targets

## TODO: illustrate subcellular locations with drug modalities
## step 1: group by subcellular_labels
## step 2: do ANOVA
## step 3: charts and bars
